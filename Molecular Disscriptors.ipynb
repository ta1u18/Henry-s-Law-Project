# %%
from rdkit import Chem
from rdkit.Chem.EnumerateStereoisomers import EnumerateStereoisomers, StereoEnumerationOptions
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import PandasTools
from rdkit.Chem import AllChem as Chem
from rdkit.Chem.EnumerateStereoisomers import EnumerateStereoisomers
from rdkit.Chem.rdDistGeom import EmbedMolecule
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
import numpy as np

import ipywidgets as widgets

# %%
#import key data columns from the merged data set
Data=pd.read_csv('MergedDataFinal1.csv')[['species','SMILES','SLN','Kh_mean','LOGKh_Mean','Kh_first','LOGKh_first','LogS','MW','MLOGP','Number of functional Groups']]

# %%
#import key data columns from the merged data set
dffulldata= pd.DataFrame(Data)
dffulldata
# Out:
#                   species                                        SMILES  \
# 0               Prometryn                    CSc1nc(NC(C)C)nc(NC(C)C)n1
# 1     3,3-Dimethylpentane                                   CCC(C)(C)CC
# 2         2-Methylpentane                                      CCCC(C)C
# 3         N-Methylaniline                                    CNc1ccccc1
# 4                1-Decene                                   C=CCCCCCCCC
# ..                    ...                                           ...
# 880             1-Nonanol                                    CCCCCCCCCO
# 881    Heptachlor epoxide  ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl
# 882          Cycloheptene                                    C1=CCCCCC1
# 883  4,6-Dinitro-O-cresol        Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O
# 884              Coumarin                              O=c1ccc2ccccc2o1
#
#                                                    SLN    Kh_mean  LOGKh_Mean  \
# ...

# %%
dfnumdata=dffulldata.drop(['species','SMILES','SLN'], axis=1)
dfnumdata
# Out:
#        Kh_mean  LOGKh_Mean   Kh_first   LOGKh_first   LogS      MW  MLOGP  \
# 0    -8.684930    0.938766  -6.709304   0.826677492 -4.100  241.41  2.893
# 1    12.132850    1.083963  12.129112   1.083828992 -4.230  100.23  3.869
# 2    11.968328    1.078033  12.040558   1.080646622 -3.740   86.20  3.516
# 3     0.061071   -1.214163   0.139262  -0.856167163 -1.280  107.17  1.859
# 4    12.564383    1.099141  12.507178   1.097159322 -5.510  140.30  4.678
# ..         ...         ...        ...           ...    ...     ...    ...
# 880   1.391882    0.143603   2.207275   0.343856427 -3.010  144.29  3.503
# 881   0.387922   -0.411256   0.733969  -0.134322179 -6.168  389.30  4.214
# 882   8.386011    0.923555   8.254829   0.916708077 -3.180   96.19  2.420
# 883  -3.303527    0.518978  -3.761200   0.575326441 -1.460  198.15  1.748
# 884  -4.605170    0.663246  -4.605170   0.663245684 -1.810  146.15  2.265
#
#      Number of functional Groups
# 0                              6
# ...

# %% [markdown]
# #plot LogS vs LogKh
# LogS_vs_LogKh = dfnumdata.plot.scatter(x='LOGKh_first'
#                                     ,y='LogS'
#                                     ,c='Blue')
# plt.title("LogS vs LogKh")
# plt.xlabel('LOGKh_first')
# plt.ylabel('LogS')

# %% [markdown]
# #plot LogP vs MW
# LogS_vs_LogKh = dfnumdata.plot.scatter(x='MW'
#                                     ,y='MLOGP'
#                                     ,c='Blue')
# plt.title("LogP vs MW")
# plt.xlabel('MW')
# plt.ylabel('MLOGP')

# %% [markdown]
# dfnumdata.hist(figsize=(20,24))

# %%
from multiprocessing import freeze_support

from rdkit import Chem

from mordred import Calculator, descriptors

if __name__ == "__main__":
    freeze_support()

    mols = [
        Chem.MolFromSmiles("c1ccccc1"),
        Chem.MolFromSmiles("c1ccccc1Cl"),
        Chem.MolFromSmiles("c1ccccc1C"),
    ]

    # Create Calculator
    calc = Calculator(descriptors)

    # map method calculate multiple molecules (return generator)
    print(list(calc.map(mols)))

    # pandas method calculate multiple molecules (return pandas DataFrame)
    print(calc.pandas(mols))
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  3.86it/s]
# ...

# %%
mol_list=[]
for Smiles in dffulldata['SMILES']:
    
    mol = Chem.MolFromSmiles(Smiles)
    mol_list.append(mol)
    
print(mol_list)
# Out:
# [<rdkit.Chem.rdchem.Mol object at 0x0000017A53983030>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983120>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983210>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983080>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983990>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983260>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983350>, <rdkit.Chem.rdchem.Mol object at 0x0000017A539839E0>, <rdkit.Chem.rdchem.Mol object at 0x0000017A539832B0>, <rdkit.Chem.rdchem.Mol object at 0x0000017A539833A0>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983530>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983300>, <rdkit.Chem.rdchem.Mol object at 0x0000017A539833F0>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983580>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983490>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983440>, <rdkit.Chem.rdchem.Mol object at 0x0000017A53983670>, <rdkit.Chem.rdchem.Mol object at 0x0000017A539834E0>, <rdkit.Chem.rdchem.Mol ob
# ...

# %%
from multiprocessing import freeze_support

from rdkit import Chem

from mordred import Calculator, descriptors

if __name__ == "__main__":
    freeze_support()



    # Create Calculator
    calc = Calculator(descriptors)

    # map method calculate multiple molecules (return generator)
    list(calc.map(mol_list))

    # pandas method calculate multiple molecules (return pandas DataFrame)
    a=(calc.pandas(mol_list))
    print(a)
# Out:
# ...
# 100%|██████████| 885/885 [00:19<00:00, 46.01it/s]
#            ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0    11.751268  10.710647      0      0  18.546937  2.315485  4.630969
# 1     4.560478   5.065697      0      0   7.595865  2.135779  4.271558
# 2     3.754314   4.057055      0      0   6.155367  1.902113  3.804226
# 3     5.656854   5.427660      0      0  10.424292  2.135779  4.271558
# 4     6.363961   6.254644      0      0  12.053348  1.918986  3.837972
# ..         ...        ...    ...    ...        ...       ...       ...
# 880   6.363961   6.254644      0      0  12.053348  1.918986  3.837972
# 881  15.134539  15.101862      0      0  23.075106  2.846524  5.291496
# 882   4.949747   4.666667      0      0   8.987918  2.000000  3.801938
# 883  10.394073   9.993198      0      0  16.365518  2.380402  4.760805
# 884   8.554231   7.309128      0      0  14.426921  2.333244  4.666488
#
# ...

# %%
print(a)
# Out:
#            ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0    11.751268  10.710647      0      0  18.546937  2.315485  4.630969
# 1     4.560478   5.065697      0      0   7.595865  2.135779  4.271558
# 2     3.754314   4.057055      0      0   6.155367  1.902113  3.804226
# 3     5.656854   5.427660      0      0  10.424292  2.135779  4.271558
# 4     6.363961   6.254644      0      0  12.053348  1.918986  3.837972
# ..         ...        ...    ...    ...        ...       ...       ...
# 880   6.363961   6.254644      0      0  12.053348  1.918986  3.837972
# 881  15.134539  15.101862      0      0  23.075106  2.846524  5.291496
# 882   4.949747   4.666667      0      0   8.987918  2.000000  3.801938
# 883  10.394073   9.993198      0      0  16.365518  2.380402  4.760805
# 884   8.554231   7.309128      0      0  14.426921  2.333244  4.666488
#
#         SpAD_A   SpMAD_A   LogEE_A  ...      SRW10     TSRW10          MW  \
# ...

# %%
a.to_csv (r'C:\Users\thoma\Desktop\moleculedisscriptors.csv', index = False, header=True)
