# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import PandasTools


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %%
#Import henrys law and wang data
Wang=pd.read_csv('Mergeddata.csv')

# %%
#make both datasets into panda
dfWang = pd.DataFrame(Wang)
dfWang
# Out:
#                         InChI_Key                              species  \
# 0     AAEVYOVXGOFMJO-UHFFFAOYSA-N                            Prometryn
# 1     AEXMKKGTQYQZCS-UHFFFAOYSA-N                  3,3-Dimethylpentane
# 2     AFABGHUZZDYHJO-UHFFFAOYSA-N                      2-Methylpentane
# 3     AFBPFSWMIHJQDM-UHFFFAOYSA-N                      N-Methylaniline
# 4     AFFLGGQVNFXPEV-UHFFFAOYSA-N                             1-Decene
# ...                           ...                                  ...
# 1034  ZXIJMRYMVAMXQP-UHFFFAOYSA-N                         Cycloheptene
# 1035  ZXVONLUNISGICL-UHFFFAOYSA-N                 4,6-Dinitro-O-cresol
# 1036  ZYGHJZDHTFUPRJ-UHFFFAOYSA-N                             Coumarin
# 1037  ZYGHJZDHTFUPRJ-UHFFFAOYSA-N                             Coumarin
# 1038  ZZCSBXFJFLSDRR-UHFFFAOYSA-N  3,4,5-Trichloro-2,6-dimethoxyphenol
#
#       Source  SubSource  SubID     NetID  \
# 0          1          2   1619  1_2_1619
# 1          1          2    118   1_2_118
# 2          2          0    332   2_0_332
# 3          1          1   1083  1_1_1083
# 4          1          2    138   1_2_138
# ...      ...        ...    ...       ...
# 1034       1          2     99    1_2_99
# 1035       1          2    860   1_2_860
# 1036       1          1   1120  1_1_1120
# 1037       2          0     85    2_0_85
# 1038       3          0    653   3_0_653
#
#                                                    SLN  \
# 0     S(CH3)C[6]=NC(=NC(=N@6)NHCH(CH3)CH3)NHCH(CH3)CH3
# 1                            C(CH2CH3)(CH2CH3)(CH3)CH3
# 2                                  CH3CH(CH2CH2CH3)CH3
# 3                           NH(CH3)C[7]=CHCH=CHCH=CH@7
# 4                     CH2(CH2CH2CH2CH3)CH2CH2CH2CH=CH2
# ...                                                ...
# 1034                         C[1]H2CH2CH2CH=CHCH2CH2@1
# 1035       N(=O)(=O)C[4]=C(C(=CHC(=CH@4)N(=O)=O)CH3)OH
# 1036                O[1]C[2]=C(CH=CHCH=CH@2)CH=CHC@1=O
# 1037                O[1]C(=O)CH=CHC[8]CH=CHCH=CHC@1=@8
# 1038          C[1](=C(C(=C(C(=C@1Cl)Cl)Cl)OCH3)OH)OCH3
#
#                                       SMILES   LogS      MW  MLOGP    Kh_mean  \
# 0                 CSc1nc(NC(C)C)nc(NC(C)C)n1 -4.100  241.41  2.893  -8.684930
# 1                                CCC(C)(C)CC -4.230  100.23  3.869  12.132850
# 2                                   CCCC(C)C -3.740   86.20  3.516  11.968328
# 3                                 CNc1ccccc1 -1.280  107.17  1.859   0.061071
# 4                                C=CCCCCCCCC -5.510  140.30  4.678  12.564383
# ...                                      ...    ...     ...    ...        ...
# 1034                              C1=CCCCCC1 -3.180   96.19  2.420   8.386011
# 1035  Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O -1.460  198.15  1.748  -3.303527
# 1036                        O=c1ccc2ccccc2o1 -1.890  146.15  2.265  -4.605170
# 1037                        O=c1ccc2ccccc2o1 -1.730  146.15  2.265  -4.605170
# 1038             COc1c(O)c(OC)c(Cl)c(Cl)c1Cl -3.411  257.50  2.192  -3.806662
#
#        Kh_first
# 0     -6.709304
# 1     12.129112
# 2     12.040558
# 3      0.139262
# 4     12.507178
# ...         ...
# 1034   8.254829
# 1035  -3.761200
# 1036  -4.605170
# 1037  -4.605170
# 1038  -3.806662
#
# [1039 rows x 13 columns]

# %%
#make a list of smiles to copy in to the code below
smiles_list = dfWang['SMILES'].tolist()
formated_smiles_list=[]
size=len(smiles_list)
for i in range(1,1038):
    x= smiles_list[i] 
    formated_smiles_list.append(x)
    
    
formated_smiles_list
# Out:
# ['CC(C)C(C)C',
#  'Cc1c[nH]c2ccccc12',
#  'C=CCCCCC',
#  'Clc1ccc(-c2ccccc2)cc1Cl',
#  'CC(C)C(C)(C)C',
#  'CCC(C)c1ccccc1',
#  'CC(Oc1cc(Cl)c(Cl)cc1Cl)C(=O)O',
#  'CCN(CC)CC',
#  'Clc1ccc(-c2cccc(Cl)c2Cl)cc1',
#  'CCc1cccc2ccccc12',
#  'COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(C)c1',
#  'COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(C)c1',
#  'ClCCOCCCl',
#  'CCCC(O)CC',
#  'CCCCSP(=O)(SCCCC)SCCCC',
#  'CC(C)N1C(=O)c2ccccc2NS1(=O)=O',
#  'Clc1cccc(Cl)c1',
#  'Clc1cccc(Cl)c1',
#  'Cc1ccc([N+](=O)[O-])cc1',
#  'CCCCCCC(C)=O',
#  'COCC(=O)N(c1c(C)cccc1C)C(C)C(=O)OC',
#  'Clc1ccc(-c2c(Cl)cc(Cl)c(Cl)c2Cl)cc1Cl',
#  'CN(N=O)C(N)=O',
#  'Clc1ccc(Oc2ccc(Cl)cc2Cl)c(Cl)c1',
#  'CCCN(CCC)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](=O)[O-]',
#  'CCCCCCO',
#  'CCCC=O',
#  'c1ccc(-c2ccccc2)cc1',
#  'CCC(C)=O',
#  'Clc1ccc(-c2cc(Cl)ccc2Cl)c(Cl)c1',
#  'CCCCCCCCCO',
#  'CC(C)CO',
#  'ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl',
#  'ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl',
#  'C1=CCCCCC1',
#  'Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O',
#  'O=c1ccc2ccccc2o1',
#  'O=c1ccc2ccccc2o1']

# %%
#make a list of molecules
mol_list=[]
for Smiles in smiles_list:
    
    mol = Chem.MolFromSmiles(Smiles)
    mol_list.append(mol)
    
mol_list
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x1f910f163a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91082d940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108693a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108693f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108694e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108695d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108696c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108697b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108698a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108698f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108699e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910869f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108660d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108661c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108662b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108663a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108663f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108664e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108665d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108666c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108667b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108668a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108668f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108669e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910866f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108650d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108651c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108652b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108653a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108653f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108654e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108655d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108656c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108657b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108658a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108658f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108659e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910865f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108670d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108671c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108672b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108673a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108673f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108674e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108675d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108676c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108677b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108678a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108678f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108679e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910867f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108680d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108681c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108682b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108683a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108683f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108684e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108685d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108686c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108687b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108688a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108688f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108689e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910868f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086c9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ca30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ca80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cb20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cb70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cbc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cc10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cc60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ccb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cd00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cd50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cda0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cdf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ce40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ce90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cf30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086cf80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086e9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ea30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ea80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ead0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086eb20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086eb70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ebc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ec10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ec60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ecb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ed00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ed50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086eda0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086edf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ee40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ee90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086eee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ef30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ef80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91082d490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086f9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fa30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fa80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fb20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fb70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fbc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fc10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fc60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fcb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fd00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fd50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fda0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fdf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fe40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fe90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086fee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ff30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91086ff80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108700d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108701c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108702b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108703a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108703f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108704e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108705d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108706c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108707b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108708a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108708f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108709e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910870f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108710d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108711c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108712b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108713a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108713f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108714e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108715d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108716c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108717b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108718a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108718f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108719e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910871f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108720d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108721c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108722b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108723a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108723f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108724e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108725d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91082d4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910edf620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108727b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108728a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108728f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108729e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910872f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108730d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108731c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108732b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108733a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108733f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108734e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108735d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108736c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108737b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108738a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108738f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108739e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910873f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108740d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108741c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108742b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108743a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108743f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108744e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108745d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108746c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108747b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108748a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108748f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108749e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910874f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108750d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108751c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108752b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108753a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108753f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108754e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108755d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108756c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108757b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108758a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108758f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108759e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910875f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108760d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108761c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108762b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108763a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108763f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108764e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108765d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108766c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108767b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108768a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108768f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108769e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910876f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108770d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108771c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108772b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108773a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108773f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108774e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108775d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108776c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108777b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108778a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108778f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108779e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910877f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108780d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108781c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108782b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108783a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108783f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108784e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108785d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108786c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108787b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108788a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108788f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108789e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910878f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108790d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108791c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108792b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108793a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108793f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108794e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108795d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108796c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108797b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108798a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108798f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f9108799e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879a30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879a80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879b20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879b70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879c10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879c60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879d00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879d50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879da0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879df0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879e40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879e90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879f30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910879f80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f910ed18f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087a9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087aa30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087aa80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087aad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ab20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ab70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087abc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ac10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ac60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087acb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ad00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ad50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ada0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087adf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ae40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ae90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087aee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087af30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087af80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b260>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b300>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b350>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b440>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b490>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b530>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b580>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b620>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b670>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b710>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b760>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b800>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b850>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b940>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b990>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087b9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ba30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087ba80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bad0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bb20>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bb70>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bbc0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bc10>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bc60>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bcb0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bd00>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bd50>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bda0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bdf0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087be40>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087be90>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bee0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bf30>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087bf80>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c030>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c080>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c120>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c170>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c210>,
#  <rdkit.Chem.rdchem.Mol at 0x1f91087c260>,
#  ...]

# %%
from rdkit import Chem
from collections import namedtuple

def merge(mol, marked, aset):
    bset = set()
    for idx in aset:
        atom = mol.GetAtomWithIdx(idx)
        for nbr in atom.GetNeighbors():
            jdx = nbr.GetIdx()
            if jdx in marked:
                marked.remove(jdx)
                bset.add(jdx)
    if not bset:
        return
    merge(mol, marked, bset)
    aset.update(bset)

# atoms connected by non-aromatic double or triple bond to any heteroatom
# c=O should not match (see fig1, box 15).  I think using A instead of * should sort that out?
PATT_DOUBLE_TRIPLE = Chem.MolFromSmarts('A=,#[!#6]')
# atoms in non aromatic carbon-carbon double or triple bonds
PATT_CC_DOUBLE_TRIPLE = Chem.MolFromSmarts('C=,#C')
# acetal carbons, i.e. sp3 carbons connected to tow or more oxygens, nitrogens or sulfurs; these O, N or S atoms must have only single bonds
PATT_ACETAL = Chem.MolFromSmarts('[CX4](-[O,N,S])-[O,N,S]')
# all atoms in oxirane, aziridine and thiirane rings
PATT_OXIRANE_ETC = Chem.MolFromSmarts('[O,N,S]1CC1')

PATT_TUPLE = (PATT_DOUBLE_TRIPLE, PATT_CC_DOUBLE_TRIPLE, PATT_ACETAL, PATT_OXIRANE_ETC)

def identify_functional_groups(mol):
    marked = set()
#mark all heteroatoms in a molecule, including halogens
    for atom in mol.GetAtoms():
        if atom.GetAtomicNum() not in (6,1): # would we ever have hydrogen?
            marked.add(atom.GetIdx())

#mark the four specific types of carbon atom
    for patt in PATT_TUPLE:
        for path in mol.GetSubstructMatches(patt):
            for atomindex in path:
                marked.add(atomindex)

#merge all connected marked atoms to a single FG
    groups = []
    while marked:
        grp = set([marked.pop()])
        merge(mol, marked, grp)
        groups.append(grp)

#extract also connected unmarked carbon atoms
    ifg = namedtuple('IFG', ['atomIds', 'atoms', 'type'])
    ifgs = []
    for g in groups:
        uca = set()
        for atomidx in g:
            for n in mol.GetAtomWithIdx(atomidx).GetNeighbors():
                if n.GetAtomicNum() == 6:
                    uca.add(n.GetIdx())
        ifgs.append(ifg(atomIds=tuple(list(g)), atoms=Chem.MolFragmentToSmiles(mol, g, canonical=True), type=Chem.MolFragmentToSmiles(mol, g.union(uca),canonical=True)))
    return ifgs

def main():
    for ix, smiles in enumerate([
        'CSc1nc(NC(C)C)nc(NC(C)C)n1',
 'CCC(C)(C)CC',
 'CCCC(C)C',
 'CNc1ccccc1',
 'C=CCCCCCCCC',
 'Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)Cl)cc1',
 'COP(=S)(OC)SCC(=O)N(C)C=O',
 'Clc1ccccc1-c1cc(Cl)c(Cl)c(Cl)c1Cl',
 'FC(F)(Cl)C(F)(Cl)Cl',
 'Clc1cc(Cl)c(Cl)c(-c2cc(Cl)cc(Cl)c2Cl)c1',
 'Clc1cc(Cl)c(Cl)c(-c2cc(Cl)cc(Cl)c2Cl)c1',
 'Nc1ccccc1Cl',
 'Clc1ccc(Cl)c(-c2cccc(Cl)c2Cl)c1',
 'Nc1ccc(C(=O)O)cc1',
 'CC1=C(C(=O)Nc2ccccc2)S(=O)(=O)CCO1',
 'CCCCCO',
 'COc1ccc(Oc2ccc(NC(=O)N(C)C)cc2)cc1',
 'CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl',
 'CCCCCCOC(C)=O',
 'Cc1ccc(C)c2ccccc12',
 'CCC(O)CC',
 'Cc1c2ccccc2c(C)c2c1ccc1ccccc12',
 'Clc1ccc(Oc2ccc(Cl)c(Cl)c2Cl)c(Cl)c1Cl',
 'CCC',
 'CCC',
 'Clc1cccc(-c2ccc(Cl)c(Cl)c2Cl)c1Cl',
 'Cc1cc(C)cc(C)c1',
 'CC(C)COC=O',
 'CCCCOC(=O)c1ccccc1C(=O)OCC(CC)CCCC',
 'c1ccc2cnccc2c1',
 'c1ccc(C2CO2)cc1',
 'CC(C)OC(=O)C(O)(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
 'O=C1C=CC(=O)C=C1',
 'O=C1C=CC(=O)C=C1',
 'COC(=O)C(C)Oc1ccc(Oc2ccc(Cl)cc2Cl)cc1',
 'C=CC(=O)OC',
 'c1cc2ccc3cccc4ccc(c1)c2c34',
 'c1cc2ccc3cccc4ccc(c1)c2c34',
 'CCCCCCCO',
 'CCCCc1c(C)nc(NCC)[nH]c1=O',
 'CCCCc1c(C)nc(NCC)nc1O',
 'FC1(F)C(F)(F)C(F)(F)C1(F)F',
 'CCNc1nc(NC(C)(C)C)nc(OC)n1',
 'FC(F)(F)C(Cl)Br',
 'CCCO',
 'O=C(O)CCCCCCCC(=O)O',
 'O=[N+]([O-])c1ccccc1Cl',
 'CCCCCCCCCCCCCC',
 'C=CCBr',
 'ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)CC3C1(Cl)C2(Cl)Cl',
 'ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)CC3C1(Cl)C2(Cl)Cl',
 'CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC',
 'CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC',
 'CCCCCCCCC',
 'CC=C(C)C',
 'CN(C)C(=O)Nc1ccc(Cl)cc1',
 'CCSC(=O)N(CC(C)C)CC(C)C',
 'CCCCCCN',
 'ClC(Cl)C(Cl)(Cl)Cl',
 'Cc1cc(C)c(O)c(C)c1',
 'Clc1cc(Cl)c(Cl)c(-c2cc(Cl)c(Cl)cc2Cl)c1',
 'ClCC1CO1',
 'CCC(C)Cl',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2Cl)c(Cl)c1Cl',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2Cl)c(Cl)c1Cl',
 'CCC(C)O',
 'O=[N+]([O-])c1ccc(O)cc1',
 'CCOP(=S)(OCC)SCSCC',
 'COP(=O)(OC)OC(Br)C(Cl)(Cl)Br',
 'CCOP(=S)(OCC)Oc1ccc2c(C)c(Cl)c(=O)oc2c1',
 'CCOP(=S)(OCC)Oc1ccc2c(C)c(Cl)c(=O)oc2c1',
 'CCCCCCCCCCCCCCCCO',
 'CCCCCCCCC(=O)OCC',
 'C#CC(C)N(C)C(=O)Nc1ccc(Cl)cc1',
 'C=CCl',
 'CC(C)CC(C)C',
 'COC(C)(C)C',
 'Clc1ccc(-c2ccc(Cl)cc2Cl)cc1',
 'CCCCCC(C)=O',
 'CCCCCCCCCCCCCCCCCCCC',
 'CCOc1cc(C=O)ccc1O',
 'C=CC(C)(O)CCC=C(C)C',
 'Clc1cc(Cl)c(Cl)c(Cl)c1Cl',
 'Clc1cc(Cl)c(Cl)c(Cl)c1Cl',
 'C=C(C)C(=O)O',
 'CCSSCC',
 'COc1ccccc1[N+](=O)[O-]',
 'Cc1cc(O)ccc1Cl',
 'C=CC(=O)OCC(C)C',
 'ClCC(Cl)CCl',
 'C#CCCCC',
 'Clc1ccc2ccccc2c1',
 'CC(C)Oc1cc(-n2nc(C(C)(C)C)oc2=O)c(Cl)cc1Cl',
 'C1=CC=CCC=C1',
 'Clc1c(Cl)c(Cl)c(Oc2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c1Cl',
 'CCCCc1c(C)nc(N(C)C)nc1O',
 'Clc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
 'Clc1ccc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c1',
 'Clc1ccc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c1',
 'Cc1c2ccccc2cc2ccccc12',
 'CCOc1ccc(NC(C)=O)cc1',
 'CCOc1ccc(NC(C)=O)cc1',
 'CCOc1ccc(NC(C)=O)cc1',
 'CCC(C)(C)Cl',
 'N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl',
 'N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl',
 'c1cc2cccc3c4cccc5cccc(c(c1)c23)c54',
 'c1cc2cccc3c4cccc5cccc(c(c1)c23)c54',
 'CCC(CO[N+](=O)[O-])O[N+](=O)[O-]',
 'CC1=CCCCC1',
 'Cc1ccccc1C',
 'CCC(C)n1c(=O)[nH]c(C)c(Br)c1=O',
 'Clc1cc(Cl)c(-c2cc(Cl)cc(Cl)c2Cl)c(Cl)c1',
 'CNC(=O)Oc1cc(C)cc(C)c1',
 'COP(=S)(Oc1cc(Cl)c(Br)cc1Cl)c1ccccc1',
 'Clc1ccc(C(c2ccccc2Cl)C(Cl)(Cl)Cl)cc1',
 'CNC(=O)Oc1cccc2ccccc12',
 'CNC(=O)Oc1cccc2ccccc12',
 'CNC(=O)Oc1cccc2ccccc12',
 'CC(C)OC(=O)Nc1cccc(Cl)c1',
 'CC(C)OC(=O)Nc1cccc(Cl)c1',
 'c1cc2c3c(cccc3c1)CC2',
 'CCCCOC',
 'Clc1ccc(-c2c(Cl)ccc(Cl)c2Cl)c(Cl)c1',
 'CCCC(C)(C)C',
 'CCC(Cl)CC',
 'c1ccc2c(c1)CCCC2',
 'CCCBr',
 'ClC(Cl)=C(Cl)Cl',
 'O=[N+]([O-])c1ccc(Cl)cc1',
 'c1ccc(Cc2ccccc2)cc1',
 'c1ccc(Cc2ccccc2)cc1',
 'CCCCCCCCCCCCCCCC',
 'Clc1ccc(Cl)c(-c2ccccc2Cl)c1',
 'FC(F)(Cl)C(F)(F)Cl',
 'COCCCNc1nc(NC(C)C)nc(SC)n1',
 'CCSC(=O)N1CCCCCC1',
 'OC(CCl)CCl',
 'ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl',
 'ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl',
 'CCSC(=O)N(CC)C1CCCCC1',
 'CC(CCO[N+](=O)[O-])O[N+](=O)[O-]',
 'CCOC(C)OCC',
 'Clc1ccc(Oc2ccc(Cl)c(Cl)c2)cc1Cl',
 'C1CCOCC1',
 'BrC(Br)Br',
 'CCC(C)c1ccccc1OC(=O)NC',
 'Clc1ccc(-c2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c1',
 'Clc1c(Cl)c(Cl)c2c(c1Cl)Oc1ccccc1O2',
 'CCCCOC(C)=O',
 'CC(N)=O',
 'CCOc1ccccc1',
 'c1ccc(Nc2ccccc2)cc1',
 'C1CCCCCC1',
 'c1ccc(N=Nc2ccccc2)cc1',
 'c1ccc(N=Nc2ccccc2)cc1',
 'CCS',
 'CCOP(=S)(OCC)SCCSCC',
 'CCCCOC(=O)c1ccccc1C(=O)OCCCC',
 'CCCCOC(=O)c1ccccc1C(=O)OCCCC',
 'Cc1cccc2c1ccc1ccccc12',
 'Nc1ccccc1[N+](=O)[O-]',
 'Cc1cccc2sc3nncn3c12',
 'CCOP(=O)(OCC)OCC',
 'CCCCc1c(C)nc(NCC)nc1OS(=O)(=O)N(C)C',
 'CCc1ccc(CC)cc1',
 'COc1ccc(NC(=O)N(C)C)cc1Cl',
 'CC12CCC(CC1=O)C2(C)C',
 'CC12CCC(CC1=O)C2(C)C',
 'Clc1cc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c(Cl)c1Cl',
 'CNC(=O)Oc1cccc2c1OC(C)(C)C2',
 'CNC(=O)Oc1cccc2c1OC(C)(C)C2',
 'CCCCOCCCC',
 'Clc1cc(Cl)c(Oc2cc(Cl)c(Cl)c(Cl)c2)cc1Cl',
 'c1ccc2nc3ccccc3cc2c1',
 'CCCCCCCCl',
 'OCC(O)C(O)C(O)C(O)CO',
 'CCCCCCCCC(=O)O',
 'CCC(=O)CC',
 'CCCC(=O)O',
 'CC(=O)CCC(C)C',
 'CC(C)[N+](=O)[O-]',
 'CCOP(=S)(OCC)Oc1cc(C)nc(C(C)C)n1',
 'CCOP(=S)(OCC)Oc1cc(C)nc(C(C)C)n1',
 'BrCBr',
 'O=C(O)c1ccc(O)cc1',
 'O=C(O)c1ccc(O)cc1',
 'CCOC(=O)CC',
 'CCOC(=O)c1ccccc1C(=O)OCC',
 'CCOC(=O)c1ccccc1C(=O)OCC',
 'CC(C)I',
 'c1ccc2c(c1)cc1ccc3cccc4ccc2c1c34',
 'c1ccc2c(c1)cc1ccc3cccc4ccc2c1c34',
 'c1ccc2c(c1)cc1ccc3cccc4ccc2c1c34',
 'ClC(Cl)Br',
 'CC(C)OC(=O)C(O)(c1ccc(Br)cc1)c1ccc(Br)cc1',
 'O=C(O)CCl',
 'Clc1c(Cl)c(Cl)c2c(c1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2',
 'CSc1nnc(C(C)(C)C)c(=O)n1N',
 'CCc1cccc(CC)c1N',
 'Clc1cc(Oc2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c(Cl)c1Cl',
 'Clc1ccc(-c2ccccc2)cc1',
 'ClC1=C(Cl)C2(Cl)C3C(Cl)C=CC3C1(Cl)C2(Cl)Cl',
 'ClC1=C(Cl)C2(Cl)C3C(Cl)C=CC3C1(Cl)C2(Cl)Cl',
 'COc1ccc(Cl)c(Cl)c1Cl',
 'Cc1ccc(C)c2c(C)cccc12',
 'C=CC1(C)OC(=O)N(c2cc(Cl)cc(Cl)c2)C1=O',
 'c1ccc2c(c1)-c1cccc3c1c-2cc1ccccc13',
 'COc1cc(Cl)c(Cl)c(Cl)c1Cl',
 'CCCCCC(=O)O',
 'CCC#N',
 'Brc1ccc(Br)c(Br)c1',
 'CCCCCCC=O',
 'CC(=O)N(C)C',
 'O=[N+]([O-])c1ccc([N+](=O)[O-])cc1',
 'Cc1cccc(C)c1C',
 'Clc1ccc(Cl)c(-c2c(Cl)ccc(Cl)c2Cl)c1Cl',
 'ClC(Br)Br',
 'Clc1ccc(Cl)c(Cl)c1Cl',
 'Clc1ccc(Cl)c(Cl)c1Cl',
 'CC(C)C(C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1)c1ccc(OC(F)F)cc1',
 'CC1CCCC1',
 'CN(C)C',
 'FC(F)(F)c1ccccc1',
 'Nc1ccccc1N',
 'Clc1c(Cl)c(Cl)c(-c2ccccc2)c(Cl)c1Cl',
 'CCN(CC)c1ccccc1',
 'Oc1cccc(O)c1',
 'CCCCCCCCCC(=O)O',
 'CC(O)C(F)(F)F',
 'Clc1ccc2c(c1)Oc1ccccc1O2',
 'CC(=O)OCC(C)C',
 'CCCCCCCCCCCCCCCCCCO',
 'CC1CO1',
 'Cc1cccc(C(=O)O)c1',
 'CCOP(=O)(OCC)SCCSCC',
 'CCCN(CCC)C(=O)SCC',
 'c1ccc2c(c1)-c1cccc3cccc-2c13',
 'c1ccc2c(c1)-c1cccc3cccc-2c13',
 'ClC1(Cl)C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl',
 'Cc1ccc(C)c(C)c1',
 'c1cc2ccc3ccc4ccc5cccc6c(c1)c2c3c4c56',
 'CCCCCCCCC=O',
 'CC1=C(C(=O)Nc2ccccc2)SCCO1',
 'Oc1ccc(Br)cc1',
 'CBr',
 'CBr',
 'COc1cc(Cl)c(Cl)cc1O',
 'c1ccc2cc3c(cc2c1)-c1cccc2cccc-3c12',
 'c1ccc2c(c1)ccc1ncccc12',
 'CCCC(=O)CCC',
 'Clc1ccc(Cl)c(-c2cc(Cl)ccc2Cl)c1',
 'CNN',
 'ClC(Cl)Cl',
 'CC(C)Cc1ccc(C(C)C(=O)O)cc1',
 'CC(C)Cc1ccc(C(C)C(=O)O)cc1',
 'CCSCc1ccccc1OC(=O)NC',
 'Nc1ccc(-c2ccc(N)cc2)cc1',
 'COc1cccc(Cl)c1Cl',
 'Cc1ccc(C(C)C)cc1',
 'Oc1ccc(Cl)cc1Cl',
 'CCCCC=O',
 'C1=CCCCC1',
 'C=CC=O',
 'C=CC=O',
 'C=CC=O',
 'Clc1cc2c(cc1Cl)Oc1cc(Cl)c(Cl)cc1O2',
 'O=[N+]([O-])c1ccc(Oc2ccc(C(F)(F)F)cc2[N+](=O)[O-])cc1',
 'CC(C)CCC(C)(C)C',
 'CC1=CC(=O)CC(C)(C)C1',
 'CCOC(=O)NCCOc1ccc(Oc2ccccc2)cc1',
 'BrC(Br)(Br)Br',
 'c1ccc2c(c1)Cc1c-2ccc2ccccc12',
 'CCCCOCN(C(=O)CCl)c1c(CC)cccc1CC',
 'CCCCOCN(C(=O)CCl)c1c(CC)cccc1CC',
 'Clc1cc(-c2ccccc2)c(Cl)c(Cl)c1Cl',
 'CC(C)CBr',
 'CCCCCCCCCCCCCCO',
 'CCCCCCCCCCCCCCO',
 'CCCCCCCCCCCCCCCCCCCCCCCCCC',
 'CCCCC(=O)OC',
 'O=C1CCCN1',
 'CN(C)CCN(Cc1cccs1)c1ccccn1',
 'CSc1ccccc1',
 'CCC(C)(C)C',
 'Oc1c(Cl)cccc1Cl',
 'CCOP(=S)(NC(C)C)Oc1ccccc1C(=O)OC(C)C',
 'Oc1cccc(Cl)c1',
 'CCCCCC1CCCC1',
 'OC1CCCCC1',
 'Cc1cccnc1C',
 'COP(=S)(OC)Oc1nc(Cl)c(Cl)cc1Cl',
 'C=CC(N)=O',
 'C=CC(N)=O',
 'Clc1cc(Cl)c2c(c1Cl)Oc1ccccc1O2',
 'Clc1cc(Cl)c2c(c1Cl)Oc1ccccc1O2',
 'CCCl',
 'C#C',
 'CCCOCC(=Nc1ccc(Cl)cc1C(F)(F)F)n1ccnc1',
 'Oc1ccc(Cl)c(Cl)c1Cl',
 'Nc1cc(Cl)cc(C(=O)O)c1Cl',
 'CCCOC(=O)CCC',
 'O=Cc1ccccc1',
 'Nc1ccc(-c2ccc(N)c(Cl)c2)cc1Cl',
 'CCI',
 'Cc1cncc(C)c1',
 'C1=Cc2cccc3cccc1c23',
 'CC(C)C(=O)C(C)C',
 'O=Cc1ccco1',
 'CCc1ccccc1C',
 'COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1',
 'COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1',
 'COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1',
 'Cc1ccccc1Cl',
 'C#CCCC',
 'ClCCBr',
 'CCCCC(=O)OCC',
 'Clc1cc(Cl)c(-c2c(Cl)cc(Cl)cc2Cl)c(Cl)c1',
 'N=C(N)N[N+](=O)[O-]',
 'COc1c(Cl)cc(Cl)c(OC)c1O',
 'COC(=O)Nc1cccc(OC(=O)Nc2cccc(C)c2)c1',
 'COC(=O)Nc1cccc(OC(=O)Nc2cccc(C)c2)c1',
 'c1ccc2cc3cc4ccccc4cc3cc2c1',
 'Clc1ccc(-c2c(Cl)cccc2Cl)cc1',
 'CCC1CCCCC1',
 'CC(C)(c1ccc(O)cc1)c1ccc(O)cc1',
 'CCCC',
 'CCCC',
 'CC(C)CCCCCOC(=O)c1ccccc1C(=O)OCCCCCC(C)C',
 'CCCCCCCCC(=O)OC',
 'CC(C)C(C)(C)O',
 'CCCCN(CCCC)CCCC',
 'CNC(=O)Oc1ccc(N(C)C)c(C)c1',
 'CCCCCCC',
 'CI',
 'CCCCCCCCN',
 'Clc1ccccc1Oc1ccccc1',
 'O=[N+]([O-])c1ccccc1O',
 'CCOC1Oc2ccc(OS(C)(=O)=O)cc2C1(C)C',
 'CCCCOC(=O)c1ccccc1C(=O)OCc1ccccc1',
 'CCCCOC(=O)c1ccccc1C(=O)OCc1ccccc1',
 'Clc1cccc(Cl)c1Oc1ccccc1',
 'CCNc1nc(NC(C)(C)C)nc(SC)n1',
 'COc1nc(NC(C)C)nc(NC(C)C)n1',
 'Oc1ccccc1Cl',
 'CNC(=O)Oc1ccccc1OC(C)C',
 'CCC(O)C(C)C',
 'Oc1ccccc1',
 'COc1c(Cl)cc(Cl)c(Cl)c1Cl',
 'Clc1ccc(-c2cc(Cl)c(Cl)cc2Cl)cc1Cl',
 'Cc1cccc(C)c1',
 'CN(C)C(=O)Nc1ccc(Oc2ccc(Cl)cc2)cc1',
 'Clc1ccc2oc3ccc(Cl)cc3c2c1',
 'Cc1ccc(O)cc1',
 'COc1c(Cl)ccc(Cl)c1C(=O)O',
 'CCc1ccccc1O',
 'c1ccc2c(c1)sc1ccccc12',
 'c1ccc2c(c1)sc1ccccc12',
 'Clc1cccc(Cl)c1-c1ccccc1',
 'O=[N+]([O-])c1ccccc1[N+](=O)[O-]',
 'Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
 'Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
 'CCCCCC=O',
 'Clc1ccccc1-c1ccccc1Cl',
 'CN(C)c1ccc(N=Nc2ccccc2)cc1',
 'Clc1cc2c(oc3cc(Cl)c(Cl)c(Cl)c32)c(Cl)c1Cl',
 'O=C(O)CCCC(=O)O',
 'N#Cc1ccccc1',
 'Clc1cc(-c2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c(Cl)c1Cl',
 'Cc1occc1C(=O)Nc1ccccc1',
 'CCCCCCCC(=O)OC',
 'Clc1cc(Cl)c(Cl)cc1Cl',
 'Clc1cc(Cl)c(Cl)cc1Cl',
 'O=C1CCCCC1',
 'COP(=S)(OC)Oc1cc(Cl)c(Cl)cc1Cl',
 'O=C1C2CC=CCC2C(=O)N1SC(Cl)(Cl)C(Cl)Cl',
 'C=CC(=O)OCC',
 'Cc1cccc(N)c1',
 'CN(C)c1ccccc1',
 'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl',
 'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl',
 'CC(=O)OC(C)C',
 'CCOC(N)=O',
 'Clc1cc(Cl)c(Cl)c(-c2c(Cl)c(Cl)cc(Cl)c2Cl)c1Cl',
 'ClCBr',
 'CCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCC',
 'CCCCNCCCC',
 'CCc1ccc(C)cc1',
 'C=CCCCCCCC',
 'Brc1cccc(Br)c1',
 'CCC[N+](=O)[O-]',
 'Cc1c2ccccc2c(C)c2ccccc12',
 'Clc1cccc2ccccc12',
 'Clc1cc(Cl)c(-c2cccc(Cl)c2Cl)cc1Cl',
 'c1ccncc1',
 'CCCCCC(C)C',
 'Oc1ccc2ccccc2c1',
 'Clc1ccc(C(c2ccccc2Cl)C(Cl)Cl)cc1',
 'CC1CCCO1',
 'Cc1ccc(NC(=O)N(C)C)cc1Cl',
 'CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC',
 'CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC',
 'CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC',
 'CC1CCCCC1NC(=O)Nc1ccccc1',
 'CCCC(C)O',
 'Cc1ccnc(C)c1',
 'CC1(C)C(C=C(Cl)Cl)C1C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1',
 'c1cc[nH]c1',
 'C=CC=C',
 'CCCCCCCCO',
 'ClCc1ccccc1',
 'CCCCCCOC(=O)c1ccccc1C(=O)OCCCCCC',
 'CCCCCCOC(=O)c1ccccc1C(=O)OCCCCCC',
 'CCCC1CCCC1',
 'C#CCC',
 'O=C(O)CCC(=O)O',
 'Clc1ccc(Cl)c(-c2ccc(Cl)c(Cl)c2)c1',
 'Oc1c(Cl)c(Cl)cc(Cl)c1Cl',
 'CCCOC=O',
 'CC(C)O',
 'CC1(C)CON(Cc2ccccc2Cl)C1=O',
 'Oc1cccc2ccccc12',
 'Oc1cccc2ccccc12',
 'Clc1ccc(Cl)c(-c2ccccc2)c1',
 'Nc1nc[nH]n1',
 'O=[N+]([O-])c1cccc(Cl)c1',
 'CCCCI',
 'Cc1ccc(CO)cc1',
 'CC(Cl)CCl',
 'CC(C)(C)CO',
 'Clc1cc(Cl)c(-c2c(Cl)cc(Cl)c(Cl)c2Cl)cc1Cl',
 'CC(C)C(=O)O',
 'CCC(=O)c1ccccc1',
 'Clc1cc2oc3cc(Cl)c(Cl)cc3c2cc1Cl',
 'Clc1cccc(-c2cccc(Cl)c2)c1',
 'CN(C)C(=S)SSC(=S)N(C)C',
 'Cc1ccc(O)c(C)c1',
 'CCc1ccccc1CC',
 'CC1CCCCC1C',
 'C=CCCCCCC',
 'CC(=O)c1ccccc1',
 'NC(=O)c1ccccc1',
 'COC(C)=O',
 'COC(C)=O',
 'CC(C)Cc1ccccc1',
 'COc1c(Cl)cccc1Cl',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2Cl)c(Cl)c1',
 'Clc1ccc(Cl)c(-c2cc(Cl)c(Cl)cc2Cl)c1',
 'Clc1ccc(Cl)c(-c2cc(Cl)c(Cl)cc2Cl)c1',
 'CCCCC(C)CC',
 'Clc1ccccc1-c1ccccc1',
 'CCOP(=S)(OCC)Oc1ccc([N+](=O)[O-])cc1',
 'CCOP(=S)(OCC)Oc1ccc([N+](=O)[O-])cc1',
 'CCOP(=S)(OCC)Oc1ccc([N+](=O)[O-])cc1',
 'Clc1ccc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)cc1Cl',
 'O=[N+]([O-])C(Cl)(Cl)Cl',
 'CCO',
 'CCC(=O)Nc1ccc(Cl)c(Cl)c1',
 'CCC(=O)Nc1ccc(Cl)c(Cl)c1',
 'COP(=S)(OC)Oc1cc(Cl)c(I)cc1Cl',
 'CN=C=S',
 'O=C1OC(=O)c2ccccc21',
 'C=C(Cl)Cl',
 'CCCCC(C=O)CC',
 'COc1ccccc1O',
 'O=C1C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl',
 'Oc1cc(Cl)c(Cl)cc1Cl',
 'c1ccc2c(c1)ccc1cc3c(ccc4ccccc43)cc12',
 'C=CCCCC',
 'Oc1c(Cl)cc(Cl)cc1Cl',
 'O=C(Nc1ccccc1)c1ccccc1I',
 'CCSCC',
 'Clc1cc(Cl)c(-c2c(Cl)ccc(Cl)c2Cl)cc1Cl',
 'CON(C)C(=O)Nc1ccc(Cl)cc1',
 'O=[N+]([O-])c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
 'Oc1ccccc1-c1ccccc1',
 'CCCCCCCI',
 'COP(=S)(OC)SCN1C(=O)c2ccccc2C1=O',
 'C1=CCCC1',
 'O=[N+]([O-])c1ccccc1',
 'O=[N+]([O-])c1ccccc1',
 'CCCCCCCCCCCCO',
 'CCCCO',
 'Cn1c(=O)on(-c2ccc(Cl)c(Cl)c2)c1=O',
 'CCCCCCCBr',
 'CCCCCCc1ccccc1',
 'Clc1ccc(Cl)c(-c2ccccc2)c1Cl',
 'Clc1cc2oc3c(Cl)c(Cl)c(Cl)c(Cl)c3c2cc1Cl',
 'OCCO',
 'C[N+](=O)[O-]',
 'CCOCCOCC',
 'Oc1cccc2cccnc12',
 'O=C(Nc1cccc(Cl)c1)OCC#CCCl',
 'CC[N+](=O)[O-]',
 'CCCOC(=O)CC',
 'CNC(=O)CSP(=S)(OC)OC',
 'Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O',
 'CC(C)N(C(=O)CCl)c1ccccc1',
 'CCNc1nc(NCC)nc(SC)n1',
 'Cc1ccc(C(C)C)c(O)c1',
 'Cc1ccc(C(C)C)c(O)c1',
 'CC(C)COC(=O)c1ccccc1C(=O)OCC(C)C',
 'CC(C)COC(=O)c1ccccc1C(=O)OCC(C)C',
 'C=C(C)CC',
 'O=[N+]([O-])OCCCCCO[N+](=O)[O-]',
 'CC(=O)OCCC(C)C',
 'CCCCCCCl',
 'CCCCCCBr',
 'CCCCBr',
 'CCCOC(=O)c1ccccc1C(=O)OCCC',
 'CCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC',
 'CCC(C)(C)O',
 'Clc1cc(Cl)c(-c2c(Cl)cccc2Cl)c(Cl)c1',
 'Clc1cc(Cl)c(-c2ccccc2)c(Cl)c1',
 'CCOC(=O)c1ccccc1',
 'O=C(O)C(=O)O',
 'CCOP(=S)(OCC)SC(CCl)N1C(=O)c2ccccc2C1=O',
 'CCOP(=S)(OCC)SC(CCl)N1C(=O)c2ccccc2C1=O',
 'Clc1ccccc1',
 'Clc1ccccc1',
 'Clc1cc(Cl)c(-c2cc(Cl)c(Cl)cc2Cl)cc1Cl',
 'CC(C)N(C(=O)SCC(Cl)=C(Cl)Cl)C(C)C',
 'CCCCCCCCCCO',
 'c1ccc2cc3ccccc3cc2c1',
 'c1ccc2cc3ccccc3cc2c1',
 'C#CC',
 'CCNc1nc(Cl)nc(NC(C)C)n1',
 'CCNc1nc(Cl)nc(NC(C)C)n1',
 'CC(Oc1ccc(Cl)cc1Cl)C(=O)O',
 'CCNc1nc(Cl)nc(NC(C)(C)C#N)n1',
 'CC(C)Br',
 'CCC=O',
 'Clc1ccc2c(c1)Oc1ccc(Cl)cc1O2',
 'Cc1[nH]c(=O)n(C(C)(C)C)c(=O)c1Cl',
 'COc1c(Cl)c(Cl)c(Cl)c(Cl)c1OC',
 'COc1c(Cl)c(Cl)c(Cl)c(Cl)c1OC',
 'CCl',
 'CCCN(CCC)c1c([N+](=O)[O-])cc(C(C)C)cc1[N+](=O)[O-]',
 'COP(=O)(OC)C(O)C(Cl)(Cl)Cl',
 'COP(=O)(OC)C(O)C(Cl)(Cl)Cl',
 'c1ccc2c(c1)Oc1ccccc1O2',
 'c1ccc2c(c1)Oc1ccccc1O2',
 'CC1CCC(C(C)C)C(=O)C1',
 'CCCC(C)Cl',
 'Clc1ccc(Br)cc1',
 'OC(c1ccc(Cl)cc1)(c1cncnc1)c1ccccc1Cl',
 'CC(C)CC(C)(C)C',
 'COc1cc(Cl)c(Cl)c(Cl)c1O',
 'c1ccc2c(c1)Cc1ccccc1-2',
 'c1ccc2c(c1)Cc1ccccc1-2',
 'COC(=O)c1ccccc1C(=O)OC',
 'COC(=O)c1ccccc1C(=O)OC',
 'COCOC',
 'Cc1ccc(C)c(O)c1',
 'C=CC#N',
 'CON(C)C(=O)Nc1ccc(Br)c(Cl)c1',
 'Clc1cccc(-c2ccccc2)c1',
 'C1CCC2CCCCC2C1',
 'CC(C)C',
 'Cc1ccc(Cl)cc1',
 'Nc1c(Cl)c(Cl)nc(C(=O)O)c1Cl',
 'C1CCNCC1',
 'CCc1ccccn1',
 'N#Cc1cc(I)c(O)c(I)c1',
 'O=[N+]([O-])c1ccc(Cl)c(Cl)c1',
 'CC(=O)CC(C)C',
 'CC(=O)CC(C)C',
 'CCCCCCCC=O',
 'CCCCCC(=O)OC',
 'Cc1ccncc1C',
 'CNc1cnn(-c2cccc(C(F)(F)F)c2)c(=O)c1Cl',
 'CCCOCC',
 'c1ccc(CNc2ncnc3[nH]cnc23)cc1',
 'Cc1cccc(C)c1O',
 'COP(=S)(OC)Oc1cc(Cl)c(Br)cc1Cl',
 'ICI',
 'CC1CCC(C)(C)C1',
 'CCCC(=O)OCC',
 'Clc1ccc(Cl)cc1',
 'Clc1ccc(Cl)cc1',
 'CCCCc1ccccc1',
 'CCNc1nc(Cl)nc(NCC)n1',
 'CCCc1ccccc1',
 'CCCCC',
 'CCN(CC)c1c([N+](=O)[O-])cc(C(F)(F)F)c(N)c1[N+](=O)[O-]',
 'Clc1cc2oc3c(Cl)c(Cl)c(Cl)cc3c2cc1Cl',
 'Cc1cccc(C)n1',
 'CCNc1ccccc1',
 'CO',
 'CCCSC(=O)N(CCC)CCC',
 'Clc1cccc(-c2cc(Cl)ccc2Cl)c1',
 'Clc1c(Cl)c(Cl)c(-c2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c(Cl)c1Cl',
 'CCSCCSP(=S)(OC)OC',
 'Clc1ccc(Cl)c(-c2ccc(Cl)c(Cl)c2Cl)c1',
 'C=CCCl',
 'Cc1cccc(Cl)c1',
 'C#CCCCCCCC',
 'COC(=O)c1ccccc1O',
 'COP(=S)(OC)Oc1ccc([N+](=O)[O-])cc1Cl',
 'CC',
 'Clc1cc(Cl)c2c(c1)Oc1c(Cl)cc(Cl)cc1O2',
 'O=C(O)COc1ccc(Cl)cc1Cl',
 'CCC(C)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O',
 'BrCCBr',
 'Nc1ccccc1',
 'Clc1ccc(Cl)c(Cl)c1',
 'Clc1ccc(Cl)c(Cl)c1',
 'Clc1cc(Cl)c(Oc2cc(Cl)c(Cl)cc2Cl)cc1Cl',
 'OCC(O)CO',
 'CCCC(=O)CC',
 'CCC(C)CC',
 'COc1cc(Cl)c(OC)cc1Cl',
 'CCCC(C)CO',
 'CCCCCOC(C)=O',
 'Clc1cc(Cl)c(Oc2ccc(Cl)c(Cl)c2Cl)cc1Cl',
 'Clc1cc(Cl)c(Oc2ccc(Cl)c(Cl)c2Cl)cc1Cl',
 'CC(C)CCO',
 'CC(=O)C(C)(C)C',
 'Clc1ccc(Oc2ccc(Cl)c(Cl)c2Cl)cc1Cl',
 'Cc1ccccc1[N+](=O)[O-]',
 'Cc1ccccc1[N+](=O)[O-]',
 'Nc1ccc(O)cc1',
 'Nc1cccc(Cl)c1',
 'COP(=S)(OC)Oc1ccc(SC)c(C)c1',
 'CCCCOCCO',
 'CCCOCCC',
 'C=Cc1ccccc1',
 'C=Cc1ccccc1',
 'Cc1ccc2cc3c(ccc4ccccc43)c3c2c1CC3',
 'Cc1ccc2cc3c(ccc4ccccc43)c3c2c1CC3',
 'c1ccc2c(c1)CCC2',
 'c1ccc2c(c1)CCC2',
 'C=C(C)CN(CC)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](=O)[O-]',
 'CC(C)c1ccc(NC(=O)N(C)C)cc1',
 'CC(C)c1ccc(NC(=O)N(C)C)cc1',
 'CCCCCc1ccccc1',
 'Clc1cccc(Cl)c1-c1c(Cl)cccc1Cl',
 'Clc1cccc(Cl)c1-c1c(Cl)cccc1Cl',
 'FC(F)(Cl)Cl',
 'CCNc1nc(NC(C)C)nc(OC)n1',
 'C=CCCC=C',
 'CCCCOC(=O)CCCCCCCCC(=O)OCCCC',
 'CCCCOC(=O)CCCCCCCCC(=O)OCCCC',
 'Fc1ccccc1',
 'Clc1ccc(Cl)c(-c2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c1',
 'CN(C)C(=O)C(c1ccccc1)c1ccccc1',
 'Brc1ccccc1',
 'CN1CSC(=S)N(C)C1',
 'ClC1=C(Cl)C2(Cl)C3C4C=CC(C4)C3C1(Cl)C2(Cl)Cl',
 'ClC1=C(Cl)C2(Cl)C3C4C=CC(C4)C3C1(Cl)C2(Cl)Cl',
 'OCCOc1ccccc1',
 'OCCOc1ccccc1',
 'Brc1cc(Br)c(Br)cc1Br',
 'OC1CCCCCC1',
 'O=[N+]([O-])OCCCCO[N+](=O)[O-]',
 'Clc1ccccc1-c1c(Cl)cc(Cl)c(Cl)c1Cl',
 'COc1ccccc1Cl',
 'Cc1cc(C)c2ccccc2c1',
 'CC(C)(C)c1ccc(O)cc1',
 'CCC(C)(C)c1ccccc1',
 'CCN(CC)C(=O)SCc1ccc(Cl)cc1',
 'Oc1ccc(O)cc1',
 'Cc1ccc2ccccc2c1',
 'CCCCCCCCCCCCCCCCCC(=O)O',
 'CSC',
 'Clc1ccc(-c2ccc(Cl)cc2Cl)c(Cl)c1',
 'ClC(Cl)C(Cl)Cl',
 'COC(=O)c1ccccc1',
 'CCC(C)CO',
 'Cc1cccc2ccccc12',
 'CC1(C)C(C=C(Cl)Cl)C1C(=O)OC(C#N)c1ccc(F)c(Oc2ccccc2)c1',
 'C=CC',
 'O=C(NC(=O)c1c(F)cccc1F)Nc1ccc(Cl)cc1',
 'O=C(NC(=O)c1c(F)cccc1F)Nc1ccc(Cl)cc1',
 'CCCCC(C)=O',
 'CC1CCC(C)CC1',
 'c1ccc2[nH]nnc2c1',
 'Nc1ccc(Cl)cc1',
 'CC(C)CCl',
 'CC(=O)O',
 'C=CCOC(=O)c1ccccc1C(=O)OCC=C',
 'C=CCOC(=O)c1ccccc1C(=O)OCC=C',
 'Fc1ccc(F)cc1',
 'ClCC(Cl)(Cl)Cl',
 'Cc1cccc(O)c1C',
 'CCC(C)C',
 'c1ccc(CCc2ccccc2)cc1',
 'Cc1ccccc1O',
 'Cc1ccc(N=CN(C)C=Nc2ccc(C)cc2C)c(C)c1',
 'Cc1ccc(N=CN(C)C=Nc2ccc(C)cc2C)c(C)c1',
 'CC12CC1(C)C(=O)N(c1cc(Cl)cc(Cl)c1)C2=O',
 'BrC(Br)C(Br)Br',
 'CCc1ccc(C(=O)NN(C(=O)c2cc(C)cc(C)c2)C(C)(C)C)cc1',
 'C=CCC=C',
 'Cc1cccc([N+](=O)[O-])c1',
 'Cc1cccc([N+](=O)[O-])c1',
 'Clc1cc(Cl)c(Cl)c(Cl)c1',
 'Clc1cc(Cl)c(Cl)c(Cl)c1',
 'CCBr',
 'COc1ccccc1',
 'O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl',
 'O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl',
 'Cc1ccc(C(C)C)cc1O',
 'CCCCCCCCCCCCCCCO',
 'Clc1cccc(Cl)c1Cl',
 'Clc1cccc(Cl)c1Cl',
 'Clc1ccccc1Cl',
 'Clc1ccccc1Cl',
 'O=Cc1ccc(O)cc1',
 'C1CCCC1',
 'CCCCCCCCCC(=O)OCC',
 'Clc1c(Cl)c(Cl)c2c(oc3c(Cl)c(Cl)c(Cl)c(Cl)c32)c1Cl',
 'Clc1ccc(-c2ccccc2Cl)cc1Cl',
 'CCCCNC(=O)n1c(NC(=O)OC)nc2ccccc21',
 'CCOP(=S)(OCC)SCSP(=S)(OCC)OCC',
 'O=[N+]([O-])c1cccc2ccccc12',
 'O=[N+]([O-])c1cccc2ccccc12',
 'O=C(Nc1ccc([N+](=O)[O-])cc1Cl)c1cc(Cl)ccc1O',
 'CCc1ccc2ccccc2c1',
 'CCC(=O)OC',
 'COc1c(O)cc(Cl)c(Cl)c1Cl',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2)c(Cl)c1',
 'COP(=S)(OC)Oc1ccc([N+](=O)[O-])cc1',
 'CC(C)C(C)C(C)C',
 'Cc1cccc(O)c1',
 'Cc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]',
 'COC(C)C',
 'CC(Cl)C(C)Cl',
 'CC(C)OC=O',
 'Sc1ccccc1',
 'OC(O)C(Cl)(Cl)Cl',
 'Cc1ccccc1N',
 'Clc1cc(Cl)c(-c2ccc(Cl)c(Cl)c2Cl)cc1Cl',
 'CCNc1nc(NC(C)C)nc(SC)n1',
 'C=CCc1ccc(O)c(OC)c1',
 'Oc1c(O)c(Cl)c(Cl)c(Cl)c1Cl',
 'C=CC(=C)C',
 'CC(C)OP(=S)(OC(C)C)SCCNS(=O)(=O)c1ccccc1',
 'O=CNC(N1CCN(C(NC=O)C(Cl)(Cl)Cl)CC1)C(Cl)(Cl)Cl',
 'Clc1ccc(Oc2ccc(Cl)c(Cl)c2Cl)c(Cl)c1',
 'CCOCC',
 'O=[N+]([O-])c1cccc(O)c1',
 'Nc1cccc2ccccc12',
 'Oc1cc(Cl)c(Cl)c(Cl)c1Cl',
 'CC(O[N+](=O)[O-])C(C)O[N+](=O)[O-]',
 'Clc1cccc(-c2c(Cl)c(Cl)cc(Cl)c2Cl)c1Cl',
 'Clc1cccc(-c2c(Cl)c(Cl)cc(Cl)c2Cl)c1Cl',
 'O=C(c1ccccc1)c1ccccc1',
 'CC(C)c1ccccc1',
 'ClC(Cl)=C(Cl)C(Cl)=C(Cl)Cl',
 'ClC(Cl)=C(Cl)C(Cl)=C(Cl)Cl',
 'Cn1c(=O)c2c(ncn2C)n(C)c1=O',
 'Clc1ccc(-c2c(Cl)cc(Cl)cc2Cl)cc1',
 'CN(C)C(=O)Nc1cccc(C(F)(F)F)c1',
 'O=C1c2ccccc2C(=O)c2ccccc21',
 'Cc1ccc(N)cc1',
 'CCCCC(CC)COC(=O)CCCCC(=O)OCC(CC)CCCC',
 'O=Cc1ccc2c(c1)OCO2',
 'CC(C)=CC1C(C(=O)OCc2cccc(Oc3ccccc3)c2)C1(C)C',
 'CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl',
 'CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl',
 'COCCOCCOC',
 'CC(Cl)Cl',
 'Cc1cccc2c(C)cccc12',
 'C=C(C)C(=C)C',
 'CNC(=O)Oc1ccccc1C1OCCO1',
 'Nc1ccc(Cl)c(Cl)c1',
 'CN1CCCC1=O',
 'CCCC(Cl)Cl',
 'Clc1ccc(Cl)c(-c2c(Cl)cccc2Cl)c1',
 'CCCCN(CC)C(=O)SCCC',
 'CCCCN(CC)C(=O)SCCC',
 'CCCCCC(=O)OCC',
 'c1ccc2[nH]ccc2c1',
 'CCCCCCC(C)O',
 'Clc1ccc2c(c1)Oc1cc(Cl)c(Cl)c(Cl)c1O2',
 'c1ccc2c(c1)c1ccccc1c1ccccc21',
 'CNC(=O)Oc1cc(C(C)(C)C)cc(C(C)(C)C)c1',
 'CCCCN(CC)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](=O)[O-]',
 'c1ccc2ncccc2c1',
 'O=C(O)COc1cc(Cl)c(Cl)cc1Cl',
 'O=C(O)COc1cc(Cl)c(Cl)cc1Cl',
 'Ic1ccccc1',
 'Ic1ccccc1',
 'O=[N+]([O-])OCC(CO[N+](=O)[O-])O[N+](=O)[O-]',
 'CCCCl',
 'Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]',
 'CCCCCCl',
 'Cc1cc(C)c(C)cc1C',
 'CCCCOP(=O)(OCCCC)OCCCC',
 'CCCC1COC(Cn2cncn2)(c2ccc(Cl)cc2Cl)O1',
 'Cc1cc(Cl)ccc1N=CN(C)C',
 'COC(=O)c1cc(Oc2ccc(Cl)cc2Cl)ccc1[N+](=O)[O-]',
 'Brc1ccc(Br)cc1',
 'CN1CC(O)N(c2nnc(C(C)(C)C)s2)C1=O',
 'CC(=O)C(C)C',
 'Cc1cc(C)cc(O)c1',
 'CCCCCCCC',
 'CCCCCCC(=O)OCC',
 'CCCCCOC(=O)CC',
 'c1ccc2c(c1)oc1ccccc12',
 'c1ccc2c(c1)oc1ccccc12',
 'c1ccc2c(c1)c1cccc3ccc4cccc2c4c31',
 'Nc1ccc([N+](=O)[O-])cc1',
 'COC=O',
 'Clc1ccc(-c2c(Cl)cc(Cl)c(Cl)c2Cl)c(Cl)c1Cl',
 'CC1CCCCC1',
 'O=[N+]([O-])c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1',
 'ClCC(Cl)Cl',
 'O=NN(c1ccccc1)c1ccccc1',
 'Clc1ccc(Cl)c(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c1',
 'ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
 'Clc1cc(Cl)c(-c2c(Cl)c(Cl)cc(Cl)c2Cl)cc1Cl',
 'Fc1cccc(F)c1',
 'Clc1ccc(-c2ccccc2Cl)cc1',
 'c1ccc2ccccc2c1',
 'Clc1ccc(Cl)c(-c2c(Cl)c(Cl)cc(Cl)c2Cl)c1',
 'c1ccccc1',
 'CCC(C)C(C)=O',
 'c1ccc2c(c1)[nH]c1ccccc12',
 'C#CC(C)OC(=O)Nc1cccc(Cl)c1',
 'CC(C)Cl',
 'NC(N)=S',
 'C#CCCCCCC',
 'Oc1cccc(Cl)c1Cl',
 'CCCN(CCC)c1c([N+](=O)[O-])cc(S(N)(=O)=O)cc1[N+](=O)[O-]',
 'OCC(O)C(O)CO',
 'OC(c1ccc(Cl)cc1)(c1ccc(Cl)cc1)C(Cl)(Cl)Cl',
 'CC(Cl)(Cl)Cl',
 'N#Cc1cc(Br)c(O)c(Br)c1',
 'CCCCCCCCCCCC(=O)OC',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2)cc1Cl',
 'CC(=O)OCC(COC(C)=O)OC(C)=O',
 'Cc1ccc(C)cc1',
 'c1ccc(Oc2ccccc2)cc1',
 'c1ccc(Oc2ccccc2)cc1',
 'Clc1cc(Cl)cc(-c2cc(Cl)cc(Cl)c2)c1',
 'CCCC(=O)OC',
 'C1=CCC=CC1',
 'O=NN1CCCCC1',
 'Clc1ccc(-c2cc(Cl)ccc2Cl)cc1',
 'OCCCc1ccccc1',
 'CCOP(=S)(OCC)SCSc1ccc(Cl)cc1',
 'CCOP(=S)(OCC)SCSc1ccc(Cl)cc1',
 'BrCCCBr',
 'CCCCCl',
 'C=C',
 'Clc1cc(Cl)c(-c2ccccc2)cc1Cl',
 'Oc1c(Cl)cc(Cl)c(Cl)c1Cl',
 'Cc1nnc(-c2ccccc2)c(=O)n1N',
 'ClC(Cl)(Cl)C(Cl)(Cl)Cl',
 'CCOC(=O)CCCCC(=O)OCC',
 'CCCCCCCC(C)=O',
 'COc1cc(Cl)c(Cl)c(Cl)c1OC',
 'CCCCCC',
 'CCCCCCCCBr',
 'CCCOC',
 'CCCOC',
 'C',
 'CNC(=O)Oc1cccc(C)c1',
 'Oc1cc(Cl)cc(Cl)c1',
 'Clc1cccc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c1Cl',
 'Clc1cccc(-c2cc(Cl)c(Cl)c(Cl)c2Cl)c1Cl',
 'C=C(C)C',
 'Clc1cccc(-c2cccc(Cl)c2Cl)c1Cl',
 'ClC1=C(Cl)C(Cl)(Cl)C(Cl)=C1Cl',
 'C=C(C)C(=O)OC',
 'C=CCC',
 'ClC(Cl)(Cl)Cl',
 'ClC(Cl)(Cl)Cl',
 'ClCC(Br)CBr',
 'CCOC=O',
 'Clc1cc2c(c(Cl)c1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2',
 'COc1c(Cl)cc(Cl)cc1Cl',
 'Clc1cc2c(cc1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2',
 'O=[N+]([O-])c1cccc([N+](=O)[O-])c1',
 'c1ccc2c(c1)ccc1c3ccccc3ccc21',
 'Clc1cc2c(oc3c(Cl)c(Cl)c(Cl)c(Cl)c32)c(Cl)c1Cl',
 'CC12CCC(CC1)C(C)(C)O2',
 'CCCNCCC',
 'Clc1ccc(-c2ccccc2)c(Cl)c1',
 'CC#N',
 'CCCC(C)(C)O',
 'CCC(C)C(C)C',
 'Cc1cc(Cl)ccc1OCC(=O)O',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2Cl)cc1Cl',
 'Cc1cccc(Br)c1',
 'CC(C)Nc1nc(Cl)nc(NC(C)C)n1',
 'C1CCCCCCC1',
 'CCCCCCCN',
 'O=C(O)Cc1ccccc1',
 'Clc1ccc2c(c1)Oc1cc(Cl)ccc1O2',
 'O=C(O)CCCCC(=O)O',
 'Cc1cc(Cl)ccc1OC(C)C(=O)O',
 'COC(=O)c1ccc(C(=O)OC)cc1',
 'COC(=O)c1ccc(C(=O)OC)cc1',
 'O=C(O)c1ccccc1',
 'CCCCS',
 'Brc1ccccc1Br',
 'CSSC',
 'OCCc1ccccc1',
 'Clc1ccc2c(c1)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2',
 'CCCCC(=O)CCCC',
 'ClCCCl',
 'C=CCC(C)C',
 'CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1cncn1',
 'OCc1ccccc1',
 'CCc1cccc(C)c1N(C(=O)CCl)C(C)COC',
 'CC(C)CC(C)O',
 'Oc1cc(Cl)cc(Cl)c1Cl',
 'Cc1cc2ccccc2cc1C',
 'Cc1ccccc1C(C)C',
 'C=C(C)CCC',
 'CCCCCCCC(=O)O',
 'Oc1ccc(Cl)cc1',
 'OCC(CO)(CO)CO',
 'CCN(CC)C(=O)C(C)Oc1cccc2ccccc12',
 'Nc1cnn(-c2ccccc2)c(=O)c1Cl',
 'Nc1cnn(-c2ccccc2)c(=O)c1Cl',
 'CCOP(=O)(OCC)Oc1ccc([N+](=O)[O-])cc1',
 'C1CCOC1',
 'Clc1cc(Cl)c(-c2ccccc2Cl)cc1Cl',
 'CCc1cccc(CC)c1N(COC)C(=O)CCl',
 'CCc1cccc(CC)c1N(COC)C(=O)CCl',
 'CCc1cccc(CC)c1N(COC)C(=O)CCl',
 'Clc1cc(Cl)c(Oc2ccc(Cl)c(Cl)c2Cl)c(Cl)c1',
 'C1CCCCC1',
 'CCOC(C)=O',
 'CC(Br)CBr',
 'Clc1cc(Cl)c(Cl)c(-c2c(Cl)c(Cl)c(Cl)c(Cl)c2Cl)c1Cl',
 'O=[N+]([O-])c1ccc(Oc2ccc(Cl)cc2Cl)cc1',
 'C=C(Cl)CSC(=S)N(CC)CC',
 'Nc1cccc([N+](=O)[O-])c1',
 'Clc1cc(Cl)cc(Cl)c1',
 'Clc1cc(Cl)cc(Cl)c1',
 'CON(C)C(=O)Nc1ccc(Cl)c(Cl)c1',
 'Clc1cc(Cl)c(Oc2cc(Cl)c(Cl)cc2Cl)c(Cl)c1',
 'CC(C)CCOC=O',
 'CCOP(=S)(OCC)SCSC(C)(C)C',
 'CCOP(=S)(OCC)SCSC(C)(C)C',
 'C=C(C)C1CC=C(C)CC1',
 'CN(C)C(=O)Nc1ccc(Cl)c(Cl)c1',
 'CN(C)C(=O)Nc1ccc(Cl)c(Cl)c1',
 'O=C(O)c1ccccc1C(=O)O',
 'O=C(O)c1ccccc1C(=O)O',
 'CCCC(C)=O',
 'CC1(C)C(C(=O)OC(C#N)c2cccc(Oc3ccccc3)c2)C1(C)C',
 'CCOP(=S)(OCC)Oc1nc(Cl)n(C(C)C)n1',
 'NC(N)=O',
 'ClC=C(Cl)Cl',
 'Cc1c([N+](=O)[O-])cccc1[N+](=O)[O-]',
 'Cc1ccc(C)nc1',
 'CN(C)C(=O)Nc1ccccc1',
 'CC(C)SC(C)C',
 'COP(=O)(NC(C)=O)SC',
 'c1ccc(NNc2ccccc2)cc1',
 'Nc1ccc(Cc2ccc(N)cc2)cc1',
 'Clc1cc(Cl)c(Oc2cc(Cl)c(Cl)c(Cl)c2Cl)cc1Cl',
 'Oc1ccccc1O',
 'Cc1ccc(O)cc1C',
 'O=C1CCCO1',
 'CNC(=O)Oc1cc(C)c(SC)c(C)c1',
 'Cc1nc(N(C)C)nc(OC(=O)N(C)C)c1C',
 'CCCN(CCC)CCC',
 'O=C(O)c1ccccc1O',
 'Cc1ccc2cc(C)ccc2c1',
 'C=CC(C)C',
 'ClCCCCl',
 'CCCCC(CC)CO',
 'CCCOC(C)=O',
 'c1ccoc1',
 'ClCCl',
 'C1COCCN1',
 'c1ccc2c(c1)ccc1ccccc12',
 'CCc1ccccc1',
 'N#Cc1c(Cl)cccc1Cl',
 'COc1ccc(Cl)cc1',
 'CCCCCCCCCC(=O)OC',
 'CC(=O)CC(C)=O',
 'Clc1ccc(-c2ccc(Cl)cc2)cc1',
 'c1ccsc1',
 'CC(C)(C)c1ccccc1',
 'COc1cccc(Cl)c1',
 'Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)(Cl)Cl)cc1',
 'Clc1ccc(C(c2ccc(Cl)cc2)C(Cl)(Cl)Cl)cc1',
 'C#CCCCCC',
 'C=CCCC',
 'Cn1cc(-c2ccccc2)c(=O)c(-c2cccc(C(F)(F)F)c2)c1',
 'Cc1ccccc1',
 'Oc1ccc(-c2ccccc2)cc1',
 'CC(C)CCBr',
 'CCCCCCCC(=O)OCC',
 'Clc1ccc(-c2ccc(Cl)c(Cl)c2)cc1',
 'CCCCCBr',
 'COc1c(O)c(Cl)c(Cl)c(Cl)c1Cl',
 'CC(C)OC(C)C',
 'CCCCCCCCC(C)=O',
 'Cc1ccc(Br)cc1',
 'ClC(Cl)=C(c1ccc(Cl)cc1)c1ccccc1Cl',
 'CCCSCCC',
 'CC(C)C(C)C',
 'Cc1c[nH]c2ccccc12',
 'C=CCCCCC',
 'Clc1ccc(-c2ccccc2)cc1Cl',
 'CC(C)C(C)(C)C',
 'CCC(C)c1ccccc1',
 'CC(Oc1cc(Cl)c(Cl)cc1Cl)C(=O)O',
 'CCN(CC)CC',
 'Clc1ccc(-c2cccc(Cl)c2Cl)cc1',
 'CCc1cccc2ccccc12',
 'COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(C)c1',
 'COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(C)c1',
 'ClCCOCCCl',
 'CCCC(O)CC',
 'CCCCSP(=O)(SCCCC)SCCCC',
 'CC(C)N1C(=O)c2ccccc2NS1(=O)=O',
 'Clc1cccc(Cl)c1',
 'Clc1cccc(Cl)c1',
 'Cc1ccc([N+](=O)[O-])cc1',
 'CCCCCCC(C)=O',
 'COCC(=O)N(c1c(C)cccc1C)C(C)C(=O)OC',
 'Clc1ccc(-c2c(Cl)cc(Cl)c(Cl)c2Cl)cc1Cl',
 'CN(N=O)C(N)=O',
 'Clc1ccc(Oc2ccc(Cl)cc2Cl)c(Cl)c1',
 'CCCN(CCC)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](=O)[O-]',
 'CCCCCCO',
 'CCCC=O',
 'c1ccc(-c2ccccc2)cc1',
 'CCC(C)=O',
 'Clc1ccc(-c2cc(Cl)ccc2Cl)c(Cl)c1',
 'CCCCCCCCCO',
 'CC(C)CO',
 'ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl',
 'ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl',
 'C1=CCCCCC1',
 'Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O',
 'O=c1ccc2ccccc2o1',
 'O=c1ccc2ccccc2o1'
    ]):
        m = Chem.MolFromSmiles(smiles)
        fgs = identify_functional_groups(m)
        print((('%2d: %d fgs'%(ix+1, len(fgs)), fgs)))
        

if __name__ == "__main__":
    main()
# Out:
# (' 1: 6 fgs', [IFG(atomIds=(1,), atoms='S', type='cSC'), IFG(atomIds=(3,), atoms='n', type='cnc'), IFG(atomIds=(5,), atoms='N', type='cNC'), IFG(atomIds=(9,), atoms='n', type='cnc'), IFG(atomIds=(11,), atoms='N', type='cNC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# (' 2: 0 fgs', [])
# (' 3: 0 fgs', [])
# (' 4: 1 fgs', [IFG(atomIds=(1,), atoms='N', type='cNC')])
# (' 5: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# (' 6: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl')])
# (' 7: 2 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(=S)S', type='COP(=S)(OC)SC'), IFG(atomIds=(8, 9, 10, 12, 13), atoms='O=CNC=O', type='CC(=O)N(C)C=O')])
# (' 8: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# (' 9: 6 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(6,), atoms='Cl', type='CCl'), IFG(atomIds=(7,), atoms='Cl', type='CCl')])
# ('10: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('11: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('12: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('13: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('14: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(5, 6, 7), atoms='O=CO', type='cC(=O)O')])
# ('15: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 12, 13, 14, 17), atoms='NC(=O)C(=CO)S(=O)=O', type='cNC(=O)C1=C(C)OCCS1(=O)=O')])
# ('16: 1 fgs', [IFG(atomIds=(5,), atoms='O', type='CO')])
# ('17: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(11, 12, 13, 14), atoms='NC(N)=O', type='cNC(=O)N(C)C')])
# ('18: 4 fgs', [IFG(atomIds=(2, 3, 4, 7), atoms='OP(O)=S', type='cOP(C)(=S)OC'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('19: 1 fgs', [IFG(atomIds=(9, 6, 7), atoms='O=CO', type='COC(C)=O')])
# ('20: 0 fgs', [])
# ('21: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='CO')])
# ('22: 0 fgs', [])
# ('23: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl')])
# ('24: 0 fgs', [])
# ('25: 0 fgs', [])
# ('26: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('27: 0 fgs', [])
# ('28: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC=O')])
# ('29: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('30: 1 fgs', [IFG(atomIds=(5,), atoms='n', type='cnc')])
# ('31: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='C1CO1', type='cC1CO1')])
# ('32: 4 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(7,), atoms='O', type='CO'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('33: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5, 6, 7), atoms='O=C1C=CC(=O)C=C1', type='O=C1C=CC(=O)C=C1')])
# ('34: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5, 6, 7), atoms='O=C1C=CC(=O)C=C1', type='O=C1C=CC(=O)C=C1')])
# ('35: 5 fgs', [IFG(atomIds=(1, 2, 3), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(6,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOc'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('36: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(=O)O', type='C=CC(=O)OC')])
# ('37: 0 fgs', [])
# ('38: 0 fgs', [])
# ('39: 1 fgs', [IFG(atomIds=(7,), atoms='O', type='CO')])
# ('40: 4 fgs', [IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(12,), atoms='[nH]', type='c[nH]c'), IFG(atomIds=(14,), atoms='O', type='c=O'), IFG(atomIds=(7,), atoms='n', type='cnc')])
# ('41: 4 fgs', [IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(12,), atoms='n', type='cnc'), IFG(atomIds=(14,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='n', type='cnc')])
# ('42: 8 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(4,), atoms='F', type='CF'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(7,), atoms='F', type='CF'), IFG(atomIds=(8,), atoms='F', type='CF'), IFG(atomIds=(10,), atoms='F', type='CF'), IFG(atomIds=(11,), atoms='F', type='CF')])
# ('43: 6 fgs', [IFG(atomIds=(2,), atoms='N', type='cNC'), IFG(atomIds=(4,), atoms='n', type='cnc'), IFG(atomIds=(6,), atoms='N', type='cNC'), IFG(atomIds=(11,), atoms='n', type='cnc'), IFG(atomIds=(13,), atoms='O', type='cOC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# ('44: 5 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='F', type='CF'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(6,), atoms='Br', type='CBr')])
# ('45: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='CO')])
# ('46: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='CC(=O)O'), IFG(atomIds=(10, 11, 12), atoms='O=CO', type='CC(=O)O')])
# ('47: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9,), atoms='Cl', type='cCl')])
# ('48: 0 fgs', [])
# ('49: 2 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('50: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('51: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('52: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(17, 18, 19), atoms='O=CO', type='cC(=O)OC')])
# ('53: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(17, 18, 19), atoms='O=CO', type='cC(=O)OC')])
# ('54: 0 fgs', [])
# ('55: 1 fgs', [IFG(atomIds=(1, 2), atoms='C=C', type='CC=C(C)C')])
# ('56: 2 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='Cl', type='cCl')])
# ('57: 1 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('58: 1 fgs', [IFG(atomIds=(6,), atoms='N', type='CN')])
# ('59: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(4,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(6,), atoms='Cl', type='CCl')])
# ('60: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='cO')])
# ('61: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('62: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2, 3, 4), atoms='C1CO1', type='CC1CO1')])
# ('63: 1 fgs', [IFG(atomIds=(4,), atoms='Cl', type='CCl')])
# ('64: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('65: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('66: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='CO')])
# ('67: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('68: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8, 9, 10), atoms='OP(O)(=S)SCS', type='COP(=S)(OC)SCSC')])
# ('69: 5 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='O=P(O)(O)O', type='COP(=O)(OC)OC'), IFG(atomIds=(8,), atoms='Br', type='CBr'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(12,), atoms='Br', type='CBr')])
# ('70: 4 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='O', type='c=O'), IFG(atomIds=(19,), atoms='o', type='coc')])
# ('71: 4 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='O', type='c=O'), IFG(atomIds=(19,), atoms='o', type='coc')])
# ('72: 1 fgs', [IFG(atomIds=(16,), atoms='O', type='CO')])
# ('73: 1 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='COC(C)=O')])
# ('74: 3 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC'), IFG(atomIds=(8, 4, 6, 7), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('75: 1 fgs', [IFG(atomIds=(0, 1, 2), atoms='C=CCl', type='C=CCl')])
# ('76: 0 fgs', [])
# ('77: 1 fgs', [IFG(atomIds=(1,), atoms='O', type='COC')])
# ('78: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('79: 1 fgs', [IFG(atomIds=(5, 7), atoms='C=O', type='CC(C)=O')])
# ('80: 0 fgs', [])
# ('81: 3 fgs', [IFG(atomIds=(2,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cO'), IFG(atomIds=(6, 7), atoms='C=O', type='cC=O')])
# ('82: 3 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC'), IFG(atomIds=(4,), atoms='O', type='CO'), IFG(atomIds=(8, 7), atoms='C=C', type='CC=C(C)C')])
# ('83: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl')])
# ('84: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl')])
# ('85: 1 fgs', [IFG(atomIds=(0, 1, 3, 4, 5), atoms='C=CC(=O)O', type='C=C(C)C(=O)O')])
# ('86: 1 fgs', [IFG(atomIds=(2, 3), atoms='SS', type='CSSC')])
# ('87: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(1,), atoms='O', type='cOC')])
# ('88: 2 fgs', [IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='O', type='cO')])
# ('89: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(=O)O', type='C=CC(=O)OC')])
# ('90: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='Cl', type='CCl')])
# ('91: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC')])
# ('92: 1 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl')])
# ('93: 6 fgs', [IFG(atomIds=(3,), atoms='O', type='cOC'), IFG(atomIds=(8, 7), atoms='nn', type='c-n(c)nc'), IFG(atomIds=(14,), atoms='o', type='coc'), IFG(atomIds=(16,), atoms='O', type='c=O'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(21,), atoms='Cl', type='cCl')])
# ('94: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 5, 6), atoms='C=CC=CC=C', type='C1=CC=CCC=C1')])
# ('95: 11 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(20,), atoms='Cl', type='cCl'), IFG(atomIds=(22,), atoms='Cl', type='cCl')])
# ('96: 4 fgs', [IFG(atomIds=(9,), atoms='N', type='cN(C)C'), IFG(atomIds=(12,), atoms='n', type='cnc'), IFG(atomIds=(14,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='n', type='cnc')])
# ('97: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('98: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('99: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('100: 0 fgs', [])
# ('101: 2 fgs', [IFG(atomIds=(8, 10, 7), atoms='NC=O', type='cNC(C)=O'), IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('102: 2 fgs', [IFG(atomIds=(8, 10, 7), atoms='NC=O', type='cNC(C)=O'), IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('103: 2 fgs', [IFG(atomIds=(8, 10, 7), atoms='NC=O', type='cNC(C)=O'), IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('104: 1 fgs', [IFG(atomIds=(5,), atoms='Cl', type='CCl')])
# ('105: 6 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10, 11), atoms='C#N', type='cC#N'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('106: 6 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10, 11), atoms='C#N', type='cC#N'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('107: 0 fgs', [])
# ('108: 0 fgs', [])
# ('109: 2 fgs', [IFG(atomIds=(4, 5, 6, 7), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]'), IFG(atomIds=(8, 9, 10, 11), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]')])
# ('110: 1 fgs', [IFG(atomIds=(1, 2), atoms='C=C', type='CC=C(C)C')])
# ('111: 0 fgs', [])
# ('112: 5 fgs', [IFG(atomIds=(4,), atoms='n', type='cn(c)C'), IFG(atomIds=(6,), atoms='O', type='c=O'), IFG(atomIds=(7,), atoms='[nH]', type='c[nH]c'), IFG(atomIds=(11,), atoms='Br', type='cBr'), IFG(atomIds=(13,), atoms='O', type='c=O')])
# ('113: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('114: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('115: 4 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='OP(O)=S', type='cOP(c)(=S)OC'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Br', type='cBr'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('116: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('117: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('118: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('119: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('120: 2 fgs', [IFG(atomIds=(3, 4, 5, 6), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('121: 2 fgs', [IFG(atomIds=(3, 4, 5, 6), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('122: 0 fgs', [])
# ('123: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='COC')])
# ('124: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('125: 0 fgs', [])
# ('126: 1 fgs', [IFG(atomIds=(3,), atoms='Cl', type='CCl')])
# ('127: 0 fgs', [])
# ('128: 1 fgs', [IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('129: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5), atoms='ClC(Cl)=C(Cl)Cl', type='ClC(Cl)=C(Cl)Cl')])
# ('130: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('131: 0 fgs', [])
# ('132: 0 fgs', [])
# ('133: 0 fgs', [])
# ('134: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl')])
# ('135: 6 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(6,), atoms='F', type='CF'), IFG(atomIds=(7,), atoms='Cl', type='CCl')])
# ('136: 7 fgs', [IFG(atomIds=(1,), atoms='O', type='COC'), IFG(atomIds=(5,), atoms='N', type='cNC'), IFG(atomIds=(7,), atoms='n', type='cnc'), IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(13,), atoms='n', type='cnc'), IFG(atomIds=(15,), atoms='S', type='cSC'), IFG(atomIds=(17,), atoms='n', type='cnc')])
# ('137: 1 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('138: 3 fgs', [IFG(atomIds=(0,), atoms='O', type='CO'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='Cl', type='CCl')])
# ('139: 6 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(10, 11, 12), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('140: 6 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(10, 11, 12), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('141: 1 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('142: 2 fgs', [IFG(atomIds=(4, 5, 6, 7), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]'), IFG(atomIds=(8, 9, 10, 11), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]')])
# ('143: 1 fgs', [IFG(atomIds=(2, 3, 5), atoms='OCO', type='COC(C)OC')])
# ('144: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('145: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='COC')])
# ('146: 3 fgs', [IFG(atomIds=(0,), atoms='Br', type='CBr'), IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('147: 1 fgs', [IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('148: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('149: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='O', type='cOc'), IFG(atomIds=(17,), atoms='O', type='cOc')])
# ('150: 1 fgs', [IFG(atomIds=(4, 5, 7), atoms='O=CO', type='COC(C)=O')])
# ('151: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='NC=O', type='CC(N)=O')])
# ('152: 1 fgs', [IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('153: 1 fgs', [IFG(atomIds=(4,), atoms='N', type='cNc')])
# ('154: 0 fgs', [])
# ('155: 1 fgs', [IFG(atomIds=(4, 5), atoms='N=N', type='cN=Nc')])
# ('156: 1 fgs', [IFG(atomIds=(4, 5), atoms='N=N', type='cN=Nc')])
# ('157: 1 fgs', [IFG(atomIds=(2,), atoms='S', type='CS')])
# ('158: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(=S)S', type='COP(=S)(OC)SC'), IFG(atomIds=(11,), atoms='S', type='CSC')])
# ('159: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('160: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('161: 0 fgs', [])
# ('162: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(8, 9, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('163: 3 fgs', [IFG(atomIds=(8, 9), atoms='nn', type='cnnc'), IFG(atomIds=(11,), atoms='n', type='cn(c)c'), IFG(atomIds=(6,), atoms='s', type='csc')])
# ('164: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='O=P(O)(O)O', type='COP(=O)(OC)OC')])
# ('165: 4 fgs', [IFG(atomIds=(7,), atoms='n', type='cnc'), IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(12,), atoms='n', type='cnc'), IFG(atomIds=(16, 17, 18, 14, 15), atoms='NS(=O)(=O)O', type='cOS(=O)(=O)N(C)C')])
# ('166: 0 fgs', [])
# ('167: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(8, 9, 6, 7), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('168: 1 fgs', [IFG(atomIds=(6, 7), atoms='C=O', type='CC(C)=O')])
# ('169: 1 fgs', [IFG(atomIds=(6, 7), atoms='C=O', type='CC(C)=O')])
# ('170: 8 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('171: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(11,), atoms='O', type='cOC')])
# ('172: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(11,), atoms='O', type='cOC')])
# ('173: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='COC')])
# ('174: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl')])
# ('175: 1 fgs', [IFG(atomIds=(4,), atoms='n', type='cnc')])
# ('176: 1 fgs', [IFG(atomIds=(7,), atoms='Cl', type='CCl')])
# ('177: 6 fgs', [IFG(atomIds=(0,), atoms='O', type='CO'), IFG(atomIds=(3,), atoms='O', type='CO'), IFG(atomIds=(5,), atoms='O', type='CO'), IFG(atomIds=(7,), atoms='O', type='CO'), IFG(atomIds=(9,), atoms='O', type='CO'), IFG(atomIds=(11,), atoms='O', type='CO')])
# ('178: 1 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='CC(=O)O')])
# ('179: 1 fgs', [IFG(atomIds=(2, 3), atoms='C=O', type='CC(C)=O')])
# ('180: 1 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='CC(=O)O')])
# ('181: 1 fgs', [IFG(atomIds=(1, 2), atoms='C=O', type='CC(C)=O')])
# ('182: 1 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=[N+][O-]', type='C[N+](=O)[O-]')])
# ('183: 3 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(13,), atoms='n', type='cnc'), IFG(atomIds=(18,), atoms='n', type='cnc')])
# ('184: 3 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(13,), atoms='n', type='cnc'), IFG(atomIds=(18,), atoms='n', type='cnc')])
# ('185: 2 fgs', [IFG(atomIds=(0,), atoms='Br', type='CBr'), IFG(atomIds=(2,), atoms='Br', type='CBr')])
# ('186: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('187: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('188: 1 fgs', [IFG(atomIds=(2, 3, 4), atoms='O=CO', type='COC(C)=O')])
# ('189: 2 fgs', [IFG(atomIds=(2, 3, 4), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(11, 12, 13), atoms='O=CO', type='cC(=O)OC')])
# ('190: 2 fgs', [IFG(atomIds=(2, 3, 4), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(11, 12, 13), atoms='O=CO', type='cC(=O)OC')])
# ('191: 1 fgs', [IFG(atomIds=(3,), atoms='I', type='CI')])
# ('192: 0 fgs', [])
# ('193: 0 fgs', [])
# ('194: 0 fgs', [])
# ('195: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('196: 4 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(7,), atoms='O', type='CO'), IFG(atomIds=(12,), atoms='Br', type='cBr'), IFG(atomIds=(19,), atoms='Br', type='cBr')])
# ('197: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='CC(=O)O'), IFG(atomIds=(4,), atoms='Cl', type='CCl')])
# ('198: 10 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='O', type='cOc'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl'), IFG(atomIds=(21,), atoms='O', type='cOc')])
# ('199: 4 fgs', [IFG(atomIds=(1,), atoms='S', type='cSC'), IFG(atomIds=(3, 4), atoms='nn', type='cnnc'), IFG(atomIds=(11,), atoms='O', type='c=O'), IFG(atomIds=(12, 13), atoms='nN', type='cn(c)N')])
# ('200: 1 fgs', [IFG(atomIds=(10,), atoms='N', type='cN')])
# ('201: 10 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='O', type='cOc'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl'), IFG(atomIds=(21,), atoms='Cl', type='cCl')])
# ('202: 1 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl')])
# ('203: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(9, 10), atoms='C=C', type='CC=CC'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('204: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(9, 10), atoms='C=C', type='CC=CC'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('205: 4 fgs', [IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('206: 0 fgs', [])
# ('207: 4 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC'), IFG(atomIds=(16, 17, 4, 5, 6, 7), atoms='O=CNC(=O)O', type='cN1C(=O)COC1=O'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('208: 0 fgs', [])
# ('209: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('210: 1 fgs', [IFG(atomIds=(5, 6, 7), atoms='O=CO', type='CC(=O)O')])
# ('211: 1 fgs', [IFG(atomIds=(2, 3), atoms='C#N', type='CC#N')])
# ('212: 3 fgs', [IFG(atomIds=(0,), atoms='Br', type='cBr'), IFG(atomIds=(5,), atoms='Br', type='cBr'), IFG(atomIds=(7,), atoms='Br', type='cBr')])
# ('213: 1 fgs', [IFG(atomIds=(6, 7), atoms='C=O', type='CC=O')])
# ('214: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='NC=O', type='CC(=O)N(C)C')])
# ('215: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(8, 9, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('216: 0 fgs', [])
# ('217: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('218: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('219: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('220: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('221: 6 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(8, 9), atoms='C#N', type='CC#N'), IFG(atomIds=(15,), atoms='O', type='cOc'), IFG(atomIds=(27,), atoms='O', type='cOC'), IFG(atomIds=(29,), atoms='F', type='CF'), IFG(atomIds=(30,), atoms='F', type='CF')])
# ('222: 0 fgs', [])
# ('223: 1 fgs', [IFG(atomIds=(1,), atoms='N', type='CN(C)C')])
# ('224: 3 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='F', type='CF')])
# ('225: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(7,), atoms='N', type='cN')])
# ('226: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('227: 1 fgs', [IFG(atomIds=(2,), atoms='N', type='cN(C)C')])
# ('228: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(6,), atoms='O', type='cO')])
# ('229: 1 fgs', [IFG(atomIds=(9, 10, 11), atoms='O=CO', type='CC(=O)O')])
# ('230: 4 fgs', [IFG(atomIds=(2,), atoms='O', type='CO'), IFG(atomIds=(4,), atoms='F', type='CF'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(6,), atoms='F', type='CF')])
# ('231: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='O', type='cOc'), IFG(atomIds=(7,), atoms='O', type='cOc')])
# ('232: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='O=CO', type='COC(C)=O')])
# ('233: 1 fgs', [IFG(atomIds=(18,), atoms='O', type='CO')])
# ('234: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='C1CO1', type='CC1CO1')])
# ('235: 1 fgs', [IFG(atomIds=(8, 6, 7), atoms='O=CO', type='cC(=O)O')])
# ('236: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='O=P(O)(O)S', type='COP(=O)(OC)SC'), IFG(atomIds=(11,), atoms='S', type='CSC')])
# ('237: 1 fgs', [IFG(atomIds=(8, 9, 3, 7), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('238: 0 fgs', [])
# ('239: 0 fgs', [])
# ('240: 12 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(4,), atoms='Cl', type='CCl'), IFG(atomIds=(6,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(19,), atoms='Cl', type='CCl'), IFG(atomIds=(21,), atoms='Cl', type='CCl')])
# ('241: 0 fgs', [])
# ('242: 0 fgs', [])
# ('243: 1 fgs', [IFG(atomIds=(8, 9), atoms='C=O', type='CC=O')])
# ('244: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 12, 15), atoms='NC(=O)C(S)=CO', type='cNC(=O)C1=C(C)OCCS1')])
# ('245: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(5,), atoms='Br', type='cBr')])
# ('246: 1 fgs', [IFG(atomIds=(1,), atoms='Br', type='CBr')])
# ('247: 1 fgs', [IFG(atomIds=(1,), atoms='Br', type='CBr')])
# ('248: 4 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(10,), atoms='O', type='cO'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('249: 0 fgs', [])
# ('250: 1 fgs', [IFG(atomIds=(9,), atoms='n', type='cnc')])
# ('251: 1 fgs', [IFG(atomIds=(3, 4), atoms='C=O', type='CC(C)=O')])
# ('252: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('253: 1 fgs', [IFG(atomIds=(1, 2), atoms='NN', type='CNN')])
# ('254: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Cl', type='CCl')])
# ('255: 1 fgs', [IFG(atomIds=(10, 11, 12), atoms='O=CO', type='CC(=O)O')])
# ('256: 1 fgs', [IFG(atomIds=(10, 11, 12), atoms='O=CO', type='CC(=O)O')])
# ('257: 2 fgs', [IFG(atomIds=(2,), atoms='S', type='CSC'), IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('258: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(9,), atoms='N', type='cN')])
# ('259: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('260: 0 fgs', [])
# ('261: 3 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl')])
# ('262: 1 fgs', [IFG(atomIds=(4, 5), atoms='C=O', type='CC=O')])
# ('263: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='CC=CC')])
# ('264: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=CC=O', type='C=CC=O')])
# ('265: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=CC=O', type='C=CC=O')])
# ('266: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=CC=O', type='C=CC=O')])
# ('267: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='O', type='cOc'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='O', type='cOc')])
# ('268: 6 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='O', type='cOc'), IFG(atomIds=(13,), atoms='F', type='CF'), IFG(atomIds=(14,), atoms='F', type='CF'), IFG(atomIds=(15,), atoms='F', type='CF'), IFG(atomIds=(18, 19, 20), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('269: 0 fgs', [])
# ('270: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='C=CC=O', type='CC(=O)C=C(C)C')])
# ('271: 3 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)O', type='CNC(=O)OC'), IFG(atomIds=(8,), atoms='O', type='cOC'), IFG(atomIds=(13,), atoms='O', type='cOc')])
# ('272: 4 fgs', [IFG(atomIds=(0,), atoms='Br', type='CBr'), IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(3,), atoms='Br', type='CBr'), IFG(atomIds=(4,), atoms='Br', type='CBr')])
# ('273: 0 fgs', [])
# ('274: 2 fgs', [IFG(atomIds=(4, 5, 6, 7, 8), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(10,), atoms='Cl', type='CCl')])
# ('275: 2 fgs', [IFG(atomIds=(4, 5, 6, 7, 8), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(10,), atoms='Cl', type='CCl')])
# ('276: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('277: 1 fgs', [IFG(atomIds=(4,), atoms='Br', type='CBr')])
# ('278: 1 fgs', [IFG(atomIds=(14,), atoms='O', type='CO')])
# ('279: 1 fgs', [IFG(atomIds=(14,), atoms='O', type='CO')])
# ('280: 0 fgs', [])
# ('281: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O')])
# ('282: 1 fgs', [IFG(atomIds=(0, 1, 5), atoms='NC=O', type='CNC(C)=O')])
# ('283: 4 fgs', [IFG(atomIds=(1,), atoms='N', type='CN(C)C'), IFG(atomIds=(11,), atoms='s', type='csc'), IFG(atomIds=(5,), atoms='N', type='cN(C)C'), IFG(atomIds=(17,), atoms='n', type='cnc')])
# ('284: 1 fgs', [IFG(atomIds=(1,), atoms='S', type='cSC')])
# ('285: 0 fgs', [])
# ('286: 3 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl')])
# ('287: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 9), atoms='NP(O)(O)=S', type='cOP(=S)(NC)OC'), IFG(atomIds=(16, 17, 18), atoms='O=CO', type='cC(=O)OC')])
# ('288: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('289: 0 fgs', [])
# ('290: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='CO')])
# ('291: 1 fgs', [IFG(atomIds=(5,), atoms='n', type='cnc')])
# ('292: 5 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(8,), atoms='n', type='cnc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('293: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(N)=O', type='C=CC(N)=O')])
# ('294: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(N)=O', type='C=CC(N)=O')])
# ('295: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='O', type='cOc'), IFG(atomIds=(16,), atoms='O', type='cOc')])
# ('296: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='O', type='cOc'), IFG(atomIds=(16,), atoms='O', type='cOc')])
# ('297: 1 fgs', [IFG(atomIds=(2,), atoms='Cl', type='CCl')])
# ('298: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#C')])
# ('299: 7 fgs', [IFG(atomIds=(3,), atoms='O', type='COC'), IFG(atomIds=(18, 5, 6), atoms='N=Cn', type='cN=C(C)n(c)c'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='F', type='CF'), IFG(atomIds=(16,), atoms='F', type='CF'), IFG(atomIds=(17,), atoms='F', type='CF'), IFG(atomIds=(21,), atoms='n', type='cnc')])
# ('300: 4 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('301: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8, 9, 7), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('302: 1 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='COC(C)=O')])
# ('303: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=O', type='cC=O')])
# ('304: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(9,), atoms='N', type='cN'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('305: 1 fgs', [IFG(atomIds=(2,), atoms='I', type='CI')])
# ('306: 1 fgs', [IFG(atomIds=(3,), atoms='n', type='cnc')])
# ('307: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='cC=Cc')])
# ('308: 1 fgs', [IFG(atomIds=(3, 4), atoms='C=O', type='CC(C)=O')])
# ('309: 2 fgs', [IFG(atomIds=(0, 1), atoms='C=O', type='cC=O'), IFG(atomIds=(6,), atoms='o', type='coc')])
# ('310: 0 fgs', [])
# ('311: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOC'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('312: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOC'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('313: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOC'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('314: 1 fgs', [IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('315: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC')])
# ('316: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('317: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O')])
# ('318: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('319: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5, 6), atoms='N=C(N)N[N+](=O)[O-]', type='N=C(N)N[N+](=O)[O-]')])
# ('320: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='O', type='cOC'), IFG(atomIds=(12,), atoms='O', type='cO')])
# ('321: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cNC(=O)Oc')])
# ('322: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cNC(=O)Oc')])
# ('323: 0 fgs', [])
# ('324: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('325: 0 fgs', [])
# ('326: 2 fgs', [IFG(atomIds=(14,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('327: 0 fgs', [])
# ('328: 0 fgs', [])
# ('329: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(17, 18, 19), atoms='O=CO', type='cC(=O)OC')])
# ('330: 1 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='COC(C)=O')])
# ('331: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='CO')])
# ('332: 1 fgs', [IFG(atomIds=(4,), atoms='N', type='CN(C)C')])
# ('333: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(9,), atoms='N', type='cN(C)C')])
# ('334: 0 fgs', [])
# ('335: 1 fgs', [IFG(atomIds=(1,), atoms='I', type='CI')])
# ('336: 1 fgs', [IFG(atomIds=(8,), atoms='N', type='CN')])
# ('337: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='O', type='cOc')])
# ('338: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9,), atoms='O', type='cO')])
# ('339: 2 fgs', [IFG(atomIds=(2, 3, 4), atoms='OCO', type='cOC(C)OC'), IFG(atomIds=(9, 10, 12, 13), atoms='O=S(=O)O', type='cOS(C)(=O)=O')])
# ('340: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('341: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('342: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='O', type='cOc'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('343: 6 fgs', [IFG(atomIds=(2,), atoms='N', type='cNC'), IFG(atomIds=(4,), atoms='n', type='cnc'), IFG(atomIds=(6,), atoms='N', type='cNC'), IFG(atomIds=(11,), atoms='n', type='cnc'), IFG(atomIds=(13,), atoms='S', type='cSC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# ('344: 6 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(3,), atoms='n', type='cnc'), IFG(atomIds=(5,), atoms='N', type='cNC'), IFG(atomIds=(9,), atoms='n', type='cnc'), IFG(atomIds=(11,), atoms='N', type='cNC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# ('345: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('346: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(11,), atoms='O', type='cOC')])
# ('347: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='CO')])
# ('348: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='cO')])
# ('349: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('350: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('351: 0 fgs', [])
# ('352: 3 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='O', type='cOc'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('353: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='o', type='coc')])
# ('354: 1 fgs', [IFG(atomIds=(5,), atoms='O', type='cO')])
# ('355: 4 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10, 11, 12), atoms='O=CO', type='cC(=O)O')])
# ('356: 1 fgs', [IFG(atomIds=(8,), atoms='O', type='cO')])
# ('357: 1 fgs', [IFG(atomIds=(6,), atoms='s', type='csc')])
# ('358: 1 fgs', [IFG(atomIds=(6,), atoms='s', type='csc')])
# ('359: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('360: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9, 10, 11), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('361: 6 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('362: 6 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('363: 1 fgs', [IFG(atomIds=(5, 6), atoms='C=O', type='CC=O')])
# ('364: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('365: 2 fgs', [IFG(atomIds=(8, 7), atoms='N=N', type='cN=Nc'), IFG(atomIds=(1,), atoms='N', type='cN(C)C')])
# ('366: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='o', type='coc'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl')])
# ('367: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='CC(=O)O'), IFG(atomIds=(8, 6, 7), atoms='O=CO', type='CC(=O)O')])
# ('368: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N')])
# ('369: 9 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(20,), atoms='Cl', type='cCl')])
# ('370: 2 fgs', [IFG(atomIds=(8, 6, 7), atoms='NC=O', type='cNC(c)=O'), IFG(atomIds=(2,), atoms='o', type='coc')])
# ('371: 1 fgs', [IFG(atomIds=(8, 9, 7), atoms='O=CO', type='COC(C)=O')])
# ('372: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('373: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('374: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=O', type='CC(C)=O')])
# ...
# ('906: 5 fgs', [IFG(atomIds=(4, 5), atoms='C=O', type='CC(C)=O'), IFG(atomIds=(7,), atoms='O', type='cOC'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(19, 15), atoms='nn', type='cnn(c)C'), IFG(atomIds=(17,), atoms='n', type='cnc')])
# ('907: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='CO')])
# ('908: 3 fgs', [IFG(atomIds=(9, 10, 11), atoms='NC=O', type='cN(C)C(C)=O'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='O', type='COC')])
# ('909: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='CO')])
# ('910: 4 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('911: 0 fgs', [])
# ('912: 0 fgs', [])
# ('913: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=C(C)C')])
# ('914: 1 fgs', [IFG(atomIds=(8, 9, 7), atoms='O=CO', type='CC(=O)O')])
# ('915: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(5,), atoms='Cl', type='cCl')])
# ('916: 4 fgs', [IFG(atomIds=(0,), atoms='O', type='CO'), IFG(atomIds=(8,), atoms='O', type='CO'), IFG(atomIds=(4,), atoms='O', type='CO'), IFG(atomIds=(6,), atoms='O', type='CO')])
# ('917: 2 fgs', [IFG(atomIds=(9,), atoms='O', type='cOC'), IFG(atomIds=(2, 5, 6), atoms='NC=O', type='CC(=O)N(C)C')])
# ('918: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(3, 4), atoms='nn', type='c-n(c)nc'), IFG(atomIds=(12,), atoms='O', type='c=O'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('919: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(3, 4), atoms='nn', type='c-n(c)nc'), IFG(atomIds=(12,), atoms='O', type='c=O'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('920: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='O=P(O)(O)O', type='cOP(=O)(OC)OC'), IFG(atomIds=(13, 14, 15), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('921: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='COC')])
# ('922: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('923: 2 fgs', [IFG(atomIds=(10, 11, 12, 14, 15), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('924: 2 fgs', [IFG(atomIds=(10, 11, 12, 14, 15), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('925: 2 fgs', [IFG(atomIds=(10, 11, 12, 14, 15), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('926: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('927: 0 fgs', [])
# ('928: 1 fgs', [IFG(atomIds=(2, 3, 5), atoms='O=CO', type='COC(C)=O')])
# ('929: 2 fgs', [IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(4,), atoms='Br', type='CBr')])
# ('930: 9 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(20,), atoms='Cl', type='cCl')])
# ('931: 4 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='O', type='cOc'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('932: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='C=CCl', type='C=C(C)Cl'), IFG(atomIds=(4, 5, 6, 7), atoms='NC(=S)S', type='CSC(=S)N(C)C')])
# ('933: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(8, 6, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('934: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('935: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('936: 3 fgs', [IFG(atomIds=(1, 2, 4, 5, 6), atoms='NC(=O)NO', type='cNC(=O)N(C)OC'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('937: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('938: 1 fgs', [IFG(atomIds=(5, 6, 7), atoms='O=CO', type='COC=O')])
# ('939: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8, 9, 10), atoms='OP(O)(=S)SCS', type='COP(=S)(OC)SCSC')])
# ('940: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8, 9, 10), atoms='OP(O)(=S)SCS', type='COP(=S)(OC)SCSC')])
# ('941: 2 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=C(C)C'), IFG(atomIds=(5, 6), atoms='C=C', type='CC=C(C)C')])
# ('942: 3 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('943: 3 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('944: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(9, 10, 11), atoms='O=CO', type='cC(=O)O')])
# ('945: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(9, 10, 11), atoms='O=CO', type='cC(=O)O')])
# ('946: 1 fgs', [IFG(atomIds=(3, 5), atoms='C=O', type='CC(C)=O')])
# ('947: 3 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(8, 9), atoms='C#N', type='CC#N'), IFG(atomIds=(15,), atoms='O', type='cOc')])
# ('948: 4 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(10,), atoms='n', type='cnc'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(17, 13), atoms='nn', type='cnn(c)C')])
# ('949: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='NC(N)=O', type='NC(N)=O')])
# ('950: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='ClC=C(Cl)Cl', type='ClC=C(Cl)Cl')])
# ('951: 2 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(10, 11, 12), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('952: 1 fgs', [IFG(atomIds=(6,), atoms='n', type='cnc')])
# ('953: 1 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C')])
# ('954: 1 fgs', [IFG(atomIds=(3,), atoms='S', type='CSC')])
# ('955: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 7, 8), atoms='O=CNP(=O)(O)S', type='COP(=O)(NC(C)=O)SC')])
# ('956: 1 fgs', [IFG(atomIds=(4, 5), atoms='NN', type='cNNc')])
# ('957: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(10,), atoms='N', type='cN')])
# ('958: 8 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('959: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('960: 1 fgs', [IFG(atomIds=(5,), atoms='O', type='cO')])
# ('961: 1 fgs', [IFG(atomIds=(0, 1, 5), atoms='O=CO', type='COC(C)=O')])
# ('962: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(10,), atoms='S', type='cSC')])
# ('963: 4 fgs', [IFG(atomIds=(2,), atoms='n', type='cnc'), IFG(atomIds=(4,), atoms='N', type='cN(C)C'), IFG(atomIds=(7,), atoms='n', type='cnc'), IFG(atomIds=(9, 10, 11, 12), atoms='NC(=O)O', type='cOC(=O)N(C)C')])
# ('964: 1 fgs', [IFG(atomIds=(3,), atoms='N', type='CN(C)C')])
# ('965: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(9,), atoms='O', type='cO')])
# ('966: 0 fgs', [])
# ('967: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# ('968: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(4,), atoms='Cl', type='CCl')])
# ('969: 1 fgs', [IFG(atomIds=(8,), atoms='O', type='CO')])
# ('970: 1 fgs', [IFG(atomIds=(3, 4, 6), atoms='O=CO', type='COC(C)=O')])
# ('971: 1 fgs', [IFG(atomIds=(3,), atoms='o', type='coc')])
# ('972: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl')])
# ('973: 2 fgs', [IFG(atomIds=(2,), atoms='O', type='COC'), IFG(atomIds=(5,), atoms='N', type='CNC')])
# ('974: 0 fgs', [])
# ('975: 0 fgs', [])
# ('976: 3 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl')])
# ('977: 2 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('978: 1 fgs', [IFG(atomIds=(9, 10, 11), atoms='O=CO', type='COC(C)=O')])
# ('979: 2 fgs', [IFG(atomIds=(1, 2), atoms='C=O', type='CC(C)=O'), IFG(atomIds=(4, 6), atoms='C=O', type='CC(C)=O')])
# ('980: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl')])
# ('981: 1 fgs', [IFG(atomIds=(3,), atoms='s', type='csc')])
# ('982: 0 fgs', [])
# ('983: 2 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('984: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('985: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('986: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC')])
# ('987: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# ('988: 5 fgs', [IFG(atomIds=(1,), atoms='n', type='cn(c)C'), IFG(atomIds=(11,), atoms='O', type='c=O'), IFG(atomIds=(19,), atoms='F', type='CF'), IFG(atomIds=(20,), atoms='F', type='CF'), IFG(atomIds=(21,), atoms='F', type='CF')])
# ('989: 0 fgs', [])
# ('990: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='cO')])
# ('991: 1 fgs', [IFG(atomIds=(5,), atoms='Br', type='CBr')])
# ('992: 1 fgs', [IFG(atomIds=(8, 9, 7), atoms='O=CO', type='COC(C)=O')])
# ('993: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('994: 1 fgs', [IFG(atomIds=(5,), atoms='Br', type='CBr')])
# ('995: 6 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='O', type='cO'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('996: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='COC')])
# ('997: 1 fgs', [IFG(atomIds=(8, 10), atoms='C=O', type='CC(C)=O')])
# ('998: 1 fgs', [IFG(atomIds=(5,), atoms='Br', type='cBr')])
# ('999: 3 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=C(Cl)Cl', type='cC(c)=C(Cl)Cl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('1000: 1 fgs', [IFG(atomIds=(3,), atoms='S', type='CSC')])
# ('1001: 0 fgs', [])
# ('1002: 1 fgs', [IFG(atomIds=(3,), atoms='[nH]', type='c[nH]c')])
# ('1003: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# ('1004: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('1005: 0 fgs', [])
# ('1006: 0 fgs', [])
# ('1007: 5 fgs', [IFG(atomIds=(2,), atoms='O', type='cOC'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(12, 13, 14), atoms='O=CO', type='CC(=O)O')])
# ('1008: 1 fgs', [IFG(atomIds=(2,), atoms='N', type='CN(C)C')])
# ('1009: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('1010: 0 fgs', [])
# ('1011: 2 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(11, 12, 13), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1012: 2 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(11, 12, 13), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1013: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='O', type='COC'), IFG(atomIds=(6,), atoms='Cl', type='CCl')])
# ('1014: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='CO')])
# ('1015: 1 fgs', [IFG(atomIds=(4, 5, 6, 7, 12), atoms='O=P(S)(S)S', type='CSP(=O)(SC)SC')])
# ('1016: 1 fgs', [IFG(atomIds=(3, 4, 5, 12, 13, 14, 15), atoms='NS(=O)(=O)NC=O', type='CN1C(=O)ccNS1(=O)=O')])
# ('1017: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('1018: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('1019: 1 fgs', [IFG(atomIds=(5, 6, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1020: 1 fgs', [IFG(atomIds=(8, 6), atoms='C=O', type='CC(C)=O')])
# ('1021: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='COC'), IFG(atomIds=(3, 4, 5), atoms='NC=O', type='cN(C)C(C)=O'), IFG(atomIds=(16, 17, 18), atoms='O=CO', type='COC(C)=O')])
# ('1022: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('1023: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 6), atoms='NC(=O)NN=O', type='CN(N=O)C(N)=O')])
# ('1024: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('1025: 6 fgs', [IFG(atomIds=(3,), atoms='N', type='cN(C)C'), IFG(atomIds=(9, 10, 11), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(15,), atoms='F', type='CF'), IFG(atomIds=(16,), atoms='F', type='CF'), IFG(atomIds=(17,), atoms='F', type='CF'), IFG(atomIds=(20, 21, 22), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1026: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='CO')])
# ('1027: 1 fgs', [IFG(atomIds=(3, 4), atoms='C=O', type='CC=O')])
# ('1028: 0 fgs', [])
# ('1029: 1 fgs', [IFG(atomIds=(2, 4), atoms='C=O', type='CC(C)=O')])
# ('1030: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('1031: 1 fgs', [IFG(atomIds=(9,), atoms='O', type='CO')])
# ('1032: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='CO')])
# ('1033: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8, 9, 7), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('1034: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8, 9, 7), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('1035: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='CC=CC')])
# ('1036: 3 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9, 10, 11), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(13,), atoms='O', type='cO')])
# ('1037: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='c=O'), IFG(atomIds=(10,), atoms='o', type='coc')])
# ('1038: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='c=O'), IFG(atomIds=(10,), atoms='o', type='coc')])

# %%
type(main())
# Out:
# (' 1: 6 fgs', [IFG(atomIds=(1,), atoms='S', type='cSC'), IFG(atomIds=(3,), atoms='n', type='cnc'), IFG(atomIds=(5,), atoms='N', type='cNC'), IFG(atomIds=(9,), atoms='n', type='cnc'), IFG(atomIds=(11,), atoms='N', type='cNC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# (' 2: 0 fgs', [])
# (' 3: 0 fgs', [])
# (' 4: 1 fgs', [IFG(atomIds=(1,), atoms='N', type='cNC')])
# (' 5: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# (' 6: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl')])
# (' 7: 2 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(=S)S', type='COP(=S)(OC)SC'), IFG(atomIds=(8, 9, 10, 12, 13), atoms='O=CNC=O', type='CC(=O)N(C)C=O')])
# (' 8: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# (' 9: 6 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(6,), atoms='Cl', type='CCl'), IFG(atomIds=(7,), atoms='Cl', type='CCl')])
# ('10: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('11: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('12: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('13: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('14: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(5, 6, 7), atoms='O=CO', type='cC(=O)O')])
# ('15: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 12, 13, 14, 17), atoms='NC(=O)C(=CO)S(=O)=O', type='cNC(=O)C1=C(C)OCCS1(=O)=O')])
# ('16: 1 fgs', [IFG(atomIds=(5,), atoms='O', type='CO')])
# ('17: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(11, 12, 13, 14), atoms='NC(N)=O', type='cNC(=O)N(C)C')])
# ('18: 4 fgs', [IFG(atomIds=(2, 3, 4, 7), atoms='OP(O)=S', type='cOP(C)(=S)OC'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('19: 1 fgs', [IFG(atomIds=(9, 6, 7), atoms='O=CO', type='COC(C)=O')])
# ('20: 0 fgs', [])
# ('21: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='CO')])
# ('22: 0 fgs', [])
# ('23: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl')])
# ('24: 0 fgs', [])
# ('25: 0 fgs', [])
# ('26: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('27: 0 fgs', [])
# ('28: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC=O')])
# ('29: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('30: 1 fgs', [IFG(atomIds=(5,), atoms='n', type='cnc')])
# ('31: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='C1CO1', type='cC1CO1')])
# ('32: 4 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(7,), atoms='O', type='CO'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('33: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5, 6, 7), atoms='O=C1C=CC(=O)C=C1', type='O=C1C=CC(=O)C=C1')])
# ('34: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5, 6, 7), atoms='O=C1C=CC(=O)C=C1', type='O=C1C=CC(=O)C=C1')])
# ('35: 5 fgs', [IFG(atomIds=(1, 2, 3), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(6,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOc'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('36: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(=O)O', type='C=CC(=O)OC')])
# ('37: 0 fgs', [])
# ('38: 0 fgs', [])
# ('39: 1 fgs', [IFG(atomIds=(7,), atoms='O', type='CO')])
# ('40: 4 fgs', [IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(12,), atoms='[nH]', type='c[nH]c'), IFG(atomIds=(14,), atoms='O', type='c=O'), IFG(atomIds=(7,), atoms='n', type='cnc')])
# ('41: 4 fgs', [IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(12,), atoms='n', type='cnc'), IFG(atomIds=(14,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='n', type='cnc')])
# ('42: 8 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(4,), atoms='F', type='CF'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(7,), atoms='F', type='CF'), IFG(atomIds=(8,), atoms='F', type='CF'), IFG(atomIds=(10,), atoms='F', type='CF'), IFG(atomIds=(11,), atoms='F', type='CF')])
# ('43: 6 fgs', [IFG(atomIds=(2,), atoms='N', type='cNC'), IFG(atomIds=(4,), atoms='n', type='cnc'), IFG(atomIds=(6,), atoms='N', type='cNC'), IFG(atomIds=(11,), atoms='n', type='cnc'), IFG(atomIds=(13,), atoms='O', type='cOC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# ('44: 5 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='F', type='CF'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(6,), atoms='Br', type='CBr')])
# ('45: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='CO')])
# ('46: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='CC(=O)O'), IFG(atomIds=(10, 11, 12), atoms='O=CO', type='CC(=O)O')])
# ('47: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9,), atoms='Cl', type='cCl')])
# ('48: 0 fgs', [])
# ('49: 2 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('50: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('51: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('52: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(17, 18, 19), atoms='O=CO', type='cC(=O)OC')])
# ('53: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(17, 18, 19), atoms='O=CO', type='cC(=O)OC')])
# ('54: 0 fgs', [])
# ('55: 1 fgs', [IFG(atomIds=(1, 2), atoms='C=C', type='CC=C(C)C')])
# ('56: 2 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='Cl', type='cCl')])
# ('57: 1 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('58: 1 fgs', [IFG(atomIds=(6,), atoms='N', type='CN')])
# ('59: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(4,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(6,), atoms='Cl', type='CCl')])
# ('60: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='cO')])
# ('61: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('62: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2, 3, 4), atoms='C1CO1', type='CC1CO1')])
# ('63: 1 fgs', [IFG(atomIds=(4,), atoms='Cl', type='CCl')])
# ('64: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('65: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('66: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='CO')])
# ('67: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('68: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8, 9, 10), atoms='OP(O)(=S)SCS', type='COP(=S)(OC)SCSC')])
# ('69: 5 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='O=P(O)(O)O', type='COP(=O)(OC)OC'), IFG(atomIds=(8,), atoms='Br', type='CBr'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(12,), atoms='Br', type='CBr')])
# ('70: 4 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='O', type='c=O'), IFG(atomIds=(19,), atoms='o', type='coc')])
# ('71: 4 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='O', type='c=O'), IFG(atomIds=(19,), atoms='o', type='coc')])
# ('72: 1 fgs', [IFG(atomIds=(16,), atoms='O', type='CO')])
# ('73: 1 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='COC(C)=O')])
# ('74: 3 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC'), IFG(atomIds=(8, 4, 6, 7), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('75: 1 fgs', [IFG(atomIds=(0, 1, 2), atoms='C=CCl', type='C=CCl')])
# ('76: 0 fgs', [])
# ('77: 1 fgs', [IFG(atomIds=(1,), atoms='O', type='COC')])
# ('78: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('79: 1 fgs', [IFG(atomIds=(5, 7), atoms='C=O', type='CC(C)=O')])
# ('80: 0 fgs', [])
# ('81: 3 fgs', [IFG(atomIds=(2,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cO'), IFG(atomIds=(6, 7), atoms='C=O', type='cC=O')])
# ('82: 3 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC'), IFG(atomIds=(4,), atoms='O', type='CO'), IFG(atomIds=(8, 7), atoms='C=C', type='CC=C(C)C')])
# ('83: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl')])
# ('84: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl')])
# ('85: 1 fgs', [IFG(atomIds=(0, 1, 3, 4, 5), atoms='C=CC(=O)O', type='C=C(C)C(=O)O')])
# ('86: 1 fgs', [IFG(atomIds=(2, 3), atoms='SS', type='CSSC')])
# ('87: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(1,), atoms='O', type='cOC')])
# ('88: 2 fgs', [IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='O', type='cO')])
# ('89: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(=O)O', type='C=CC(=O)OC')])
# ('90: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='Cl', type='CCl')])
# ('91: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC')])
# ('92: 1 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl')])
# ('93: 6 fgs', [IFG(atomIds=(3,), atoms='O', type='cOC'), IFG(atomIds=(8, 7), atoms='nn', type='c-n(c)nc'), IFG(atomIds=(14,), atoms='o', type='coc'), IFG(atomIds=(16,), atoms='O', type='c=O'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(21,), atoms='Cl', type='cCl')])
# ('94: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 5, 6), atoms='C=CC=CC=C', type='C1=CC=CCC=C1')])
# ('95: 11 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(20,), atoms='Cl', type='cCl'), IFG(atomIds=(22,), atoms='Cl', type='cCl')])
# ('96: 4 fgs', [IFG(atomIds=(9,), atoms='N', type='cN(C)C'), IFG(atomIds=(12,), atoms='n', type='cnc'), IFG(atomIds=(14,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='n', type='cnc')])
# ('97: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('98: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('99: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('100: 0 fgs', [])
# ('101: 2 fgs', [IFG(atomIds=(8, 10, 7), atoms='NC=O', type='cNC(C)=O'), IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('102: 2 fgs', [IFG(atomIds=(8, 10, 7), atoms='NC=O', type='cNC(C)=O'), IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('103: 2 fgs', [IFG(atomIds=(8, 10, 7), atoms='NC=O', type='cNC(C)=O'), IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('104: 1 fgs', [IFG(atomIds=(5,), atoms='Cl', type='CCl')])
# ('105: 6 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10, 11), atoms='C#N', type='cC#N'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('106: 6 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10, 11), atoms='C#N', type='cC#N'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('107: 0 fgs', [])
# ('108: 0 fgs', [])
# ('109: 2 fgs', [IFG(atomIds=(4, 5, 6, 7), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]'), IFG(atomIds=(8, 9, 10, 11), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]')])
# ('110: 1 fgs', [IFG(atomIds=(1, 2), atoms='C=C', type='CC=C(C)C')])
# ('111: 0 fgs', [])
# ('112: 5 fgs', [IFG(atomIds=(4,), atoms='n', type='cn(c)C'), IFG(atomIds=(6,), atoms='O', type='c=O'), IFG(atomIds=(7,), atoms='[nH]', type='c[nH]c'), IFG(atomIds=(11,), atoms='Br', type='cBr'), IFG(atomIds=(13,), atoms='O', type='c=O')])
# ('113: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('114: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('115: 4 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='OP(O)=S', type='cOP(c)(=S)OC'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Br', type='cBr'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('116: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('117: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('118: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('119: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('120: 2 fgs', [IFG(atomIds=(3, 4, 5, 6), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('121: 2 fgs', [IFG(atomIds=(3, 4, 5, 6), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('122: 0 fgs', [])
# ('123: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='COC')])
# ('124: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('125: 0 fgs', [])
# ('126: 1 fgs', [IFG(atomIds=(3,), atoms='Cl', type='CCl')])
# ('127: 0 fgs', [])
# ('128: 1 fgs', [IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('129: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5), atoms='ClC(Cl)=C(Cl)Cl', type='ClC(Cl)=C(Cl)Cl')])
# ('130: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('131: 0 fgs', [])
# ('132: 0 fgs', [])
# ('133: 0 fgs', [])
# ('134: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl')])
# ('135: 6 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(6,), atoms='F', type='CF'), IFG(atomIds=(7,), atoms='Cl', type='CCl')])
# ('136: 7 fgs', [IFG(atomIds=(1,), atoms='O', type='COC'), IFG(atomIds=(5,), atoms='N', type='cNC'), IFG(atomIds=(7,), atoms='n', type='cnc'), IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(13,), atoms='n', type='cnc'), IFG(atomIds=(15,), atoms='S', type='cSC'), IFG(atomIds=(17,), atoms='n', type='cnc')])
# ('137: 1 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('138: 3 fgs', [IFG(atomIds=(0,), atoms='O', type='CO'), IFG(atomIds=(3,), atoms='Cl', type='CCl'), IFG(atomIds=(5,), atoms='Cl', type='CCl')])
# ('139: 6 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(10, 11, 12), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('140: 6 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(10, 11, 12), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('141: 1 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('142: 2 fgs', [IFG(atomIds=(4, 5, 6, 7), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]'), IFG(atomIds=(8, 9, 10, 11), atoms='O=[N+]([O-])O', type='CO[N+](=O)[O-]')])
# ('143: 1 fgs', [IFG(atomIds=(2, 3, 5), atoms='OCO', type='COC(C)OC')])
# ('144: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('145: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='COC')])
# ('146: 3 fgs', [IFG(atomIds=(0,), atoms='Br', type='CBr'), IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('147: 1 fgs', [IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('148: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('149: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='O', type='cOc'), IFG(atomIds=(17,), atoms='O', type='cOc')])
# ('150: 1 fgs', [IFG(atomIds=(4, 5, 7), atoms='O=CO', type='COC(C)=O')])
# ('151: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='NC=O', type='CC(N)=O')])
# ('152: 1 fgs', [IFG(atomIds=(2,), atoms='O', type='cOC')])
# ('153: 1 fgs', [IFG(atomIds=(4,), atoms='N', type='cNc')])
# ('154: 0 fgs', [])
# ('155: 1 fgs', [IFG(atomIds=(4, 5), atoms='N=N', type='cN=Nc')])
# ('156: 1 fgs', [IFG(atomIds=(4, 5), atoms='N=N', type='cN=Nc')])
# ('157: 1 fgs', [IFG(atomIds=(2,), atoms='S', type='CS')])
# ('158: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(=S)S', type='COP(=S)(OC)SC'), IFG(atomIds=(11,), atoms='S', type='CSC')])
# ('159: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('160: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('161: 0 fgs', [])
# ('162: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(8, 9, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('163: 3 fgs', [IFG(atomIds=(8, 9), atoms='nn', type='cnnc'), IFG(atomIds=(11,), atoms='n', type='cn(c)c'), IFG(atomIds=(6,), atoms='s', type='csc')])
# ('164: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='O=P(O)(O)O', type='COP(=O)(OC)OC')])
# ('165: 4 fgs', [IFG(atomIds=(7,), atoms='n', type='cnc'), IFG(atomIds=(9,), atoms='N', type='cNC'), IFG(atomIds=(12,), atoms='n', type='cnc'), IFG(atomIds=(16, 17, 18, 14, 15), atoms='NS(=O)(=O)O', type='cOS(=O)(=O)N(C)C')])
# ('166: 0 fgs', [])
# ('167: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(8, 9, 6, 7), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('168: 1 fgs', [IFG(atomIds=(6, 7), atoms='C=O', type='CC(C)=O')])
# ('169: 1 fgs', [IFG(atomIds=(6, 7), atoms='C=O', type='CC(C)=O')])
# ('170: 8 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('171: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(11,), atoms='O', type='cOC')])
# ('172: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(11,), atoms='O', type='cOC')])
# ('173: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='COC')])
# ('174: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl')])
# ('175: 1 fgs', [IFG(atomIds=(4,), atoms='n', type='cnc')])
# ('176: 1 fgs', [IFG(atomIds=(7,), atoms='Cl', type='CCl')])
# ('177: 6 fgs', [IFG(atomIds=(0,), atoms='O', type='CO'), IFG(atomIds=(3,), atoms='O', type='CO'), IFG(atomIds=(5,), atoms='O', type='CO'), IFG(atomIds=(7,), atoms='O', type='CO'), IFG(atomIds=(9,), atoms='O', type='CO'), IFG(atomIds=(11,), atoms='O', type='CO')])
# ('178: 1 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='CC(=O)O')])
# ('179: 1 fgs', [IFG(atomIds=(2, 3), atoms='C=O', type='CC(C)=O')])
# ('180: 1 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='CC(=O)O')])
# ('181: 1 fgs', [IFG(atomIds=(1, 2), atoms='C=O', type='CC(C)=O')])
# ('182: 1 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=[N+][O-]', type='C[N+](=O)[O-]')])
# ('183: 3 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(13,), atoms='n', type='cnc'), IFG(atomIds=(18,), atoms='n', type='cnc')])
# ('184: 3 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(13,), atoms='n', type='cnc'), IFG(atomIds=(18,), atoms='n', type='cnc')])
# ('185: 2 fgs', [IFG(atomIds=(0,), atoms='Br', type='CBr'), IFG(atomIds=(2,), atoms='Br', type='CBr')])
# ('186: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('187: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('188: 1 fgs', [IFG(atomIds=(2, 3, 4), atoms='O=CO', type='COC(C)=O')])
# ('189: 2 fgs', [IFG(atomIds=(2, 3, 4), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(11, 12, 13), atoms='O=CO', type='cC(=O)OC')])
# ('190: 2 fgs', [IFG(atomIds=(2, 3, 4), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(11, 12, 13), atoms='O=CO', type='cC(=O)OC')])
# ('191: 1 fgs', [IFG(atomIds=(3,), atoms='I', type='CI')])
# ('192: 0 fgs', [])
# ('193: 0 fgs', [])
# ('194: 0 fgs', [])
# ('195: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('196: 4 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(7,), atoms='O', type='CO'), IFG(atomIds=(12,), atoms='Br', type='cBr'), IFG(atomIds=(19,), atoms='Br', type='cBr')])
# ('197: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='CC(=O)O'), IFG(atomIds=(4,), atoms='Cl', type='CCl')])
# ('198: 10 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='O', type='cOc'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl'), IFG(atomIds=(21,), atoms='O', type='cOc')])
# ('199: 4 fgs', [IFG(atomIds=(1,), atoms='S', type='cSC'), IFG(atomIds=(3, 4), atoms='nn', type='cnnc'), IFG(atomIds=(11,), atoms='O', type='c=O'), IFG(atomIds=(12, 13), atoms='nN', type='cn(c)N')])
# ('200: 1 fgs', [IFG(atomIds=(10,), atoms='N', type='cN')])
# ('201: 10 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='O', type='cOc'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl'), IFG(atomIds=(21,), atoms='Cl', type='cCl')])
# ('202: 1 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl')])
# ('203: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(9, 10), atoms='C=C', type='CC=CC'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('204: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(9, 10), atoms='C=C', type='CC=CC'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('205: 4 fgs', [IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('206: 0 fgs', [])
# ('207: 4 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC'), IFG(atomIds=(16, 17, 4, 5, 6, 7), atoms='O=CNC(=O)O', type='cN1C(=O)COC1=O'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('208: 0 fgs', [])
# ('209: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('210: 1 fgs', [IFG(atomIds=(5, 6, 7), atoms='O=CO', type='CC(=O)O')])
# ('211: 1 fgs', [IFG(atomIds=(2, 3), atoms='C#N', type='CC#N')])
# ('212: 3 fgs', [IFG(atomIds=(0,), atoms='Br', type='cBr'), IFG(atomIds=(5,), atoms='Br', type='cBr'), IFG(atomIds=(7,), atoms='Br', type='cBr')])
# ('213: 1 fgs', [IFG(atomIds=(6, 7), atoms='C=O', type='CC=O')])
# ('214: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='NC=O', type='CC(=O)N(C)C')])
# ('215: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(8, 9, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('216: 0 fgs', [])
# ('217: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('218: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('219: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('220: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('221: 6 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(8, 9), atoms='C#N', type='CC#N'), IFG(atomIds=(15,), atoms='O', type='cOc'), IFG(atomIds=(27,), atoms='O', type='cOC'), IFG(atomIds=(29,), atoms='F', type='CF'), IFG(atomIds=(30,), atoms='F', type='CF')])
# ('222: 0 fgs', [])
# ('223: 1 fgs', [IFG(atomIds=(1,), atoms='N', type='CN(C)C')])
# ('224: 3 fgs', [IFG(atomIds=(0,), atoms='F', type='CF'), IFG(atomIds=(2,), atoms='F', type='CF'), IFG(atomIds=(3,), atoms='F', type='CF')])
# ('225: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(7,), atoms='N', type='cN')])
# ('226: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('227: 1 fgs', [IFG(atomIds=(2,), atoms='N', type='cN(C)C')])
# ('228: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(6,), atoms='O', type='cO')])
# ('229: 1 fgs', [IFG(atomIds=(9, 10, 11), atoms='O=CO', type='CC(=O)O')])
# ('230: 4 fgs', [IFG(atomIds=(2,), atoms='O', type='CO'), IFG(atomIds=(4,), atoms='F', type='CF'), IFG(atomIds=(5,), atoms='F', type='CF'), IFG(atomIds=(6,), atoms='F', type='CF')])
# ('231: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='O', type='cOc'), IFG(atomIds=(7,), atoms='O', type='cOc')])
# ('232: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='O=CO', type='COC(C)=O')])
# ('233: 1 fgs', [IFG(atomIds=(18,), atoms='O', type='CO')])
# ('234: 1 fgs', [IFG(atomIds=(1, 2, 3), atoms='C1CO1', type='CC1CO1')])
# ('235: 1 fgs', [IFG(atomIds=(8, 6, 7), atoms='O=CO', type='cC(=O)O')])
# ('236: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='O=P(O)(O)S', type='COP(=O)(OC)SC'), IFG(atomIds=(11,), atoms='S', type='CSC')])
# ('237: 1 fgs', [IFG(atomIds=(8, 9, 3, 7), atoms='NC(=O)S', type='CSC(=O)N(C)C')])
# ('238: 0 fgs', [])
# ('239: 0 fgs', [])
# ('240: 12 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(4,), atoms='Cl', type='CCl'), IFG(atomIds=(6,), atoms='Cl', type='CCl'), IFG(atomIds=(8,), atoms='Cl', type='CCl'), IFG(atomIds=(10,), atoms='Cl', type='CCl'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(19,), atoms='Cl', type='CCl'), IFG(atomIds=(21,), atoms='Cl', type='CCl')])
# ('241: 0 fgs', [])
# ('242: 0 fgs', [])
# ('243: 1 fgs', [IFG(atomIds=(8, 9), atoms='C=O', type='CC=O')])
# ('244: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 12, 15), atoms='NC(=O)C(S)=CO', type='cNC(=O)C1=C(C)OCCS1')])
# ('245: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(5,), atoms='Br', type='cBr')])
# ('246: 1 fgs', [IFG(atomIds=(1,), atoms='Br', type='CBr')])
# ('247: 1 fgs', [IFG(atomIds=(1,), atoms='Br', type='CBr')])
# ('248: 4 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(10,), atoms='O', type='cO'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('249: 0 fgs', [])
# ('250: 1 fgs', [IFG(atomIds=(9,), atoms='n', type='cnc')])
# ('251: 1 fgs', [IFG(atomIds=(3, 4), atoms='C=O', type='CC(C)=O')])
# ('252: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('253: 1 fgs', [IFG(atomIds=(1, 2), atoms='NN', type='CNN')])
# ('254: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Cl', type='CCl')])
# ('255: 1 fgs', [IFG(atomIds=(10, 11, 12), atoms='O=CO', type='CC(=O)O')])
# ('256: 1 fgs', [IFG(atomIds=(10, 11, 12), atoms='O=CO', type='CC(=O)O')])
# ('257: 2 fgs', [IFG(atomIds=(2,), atoms='S', type='CSC'), IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cOC(=O)NC')])
# ('258: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(9,), atoms='N', type='cN')])
# ('259: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('260: 0 fgs', [])
# ('261: 3 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl')])
# ('262: 1 fgs', [IFG(atomIds=(4, 5), atoms='C=O', type='CC=O')])
# ('263: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='CC=CC')])
# ('264: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=CC=O', type='C=CC=O')])
# ('265: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=CC=O', type='C=CC=O')])
# ('266: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=CC=O', type='C=CC=O')])
# ('267: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='O', type='cOc'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='O', type='cOc')])
# ('268: 6 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='O', type='cOc'), IFG(atomIds=(13,), atoms='F', type='CF'), IFG(atomIds=(14,), atoms='F', type='CF'), IFG(atomIds=(15,), atoms='F', type='CF'), IFG(atomIds=(18, 19, 20), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('269: 0 fgs', [])
# ('270: 1 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='C=CC=O', type='CC(=O)C=C(C)C')])
# ('271: 3 fgs', [IFG(atomIds=(2, 3, 4, 5), atoms='NC(=O)O', type='CNC(=O)OC'), IFG(atomIds=(8,), atoms='O', type='cOC'), IFG(atomIds=(13,), atoms='O', type='cOc')])
# ('272: 4 fgs', [IFG(atomIds=(0,), atoms='Br', type='CBr'), IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(3,), atoms='Br', type='CBr'), IFG(atomIds=(4,), atoms='Br', type='CBr')])
# ('273: 0 fgs', [])
# ('274: 2 fgs', [IFG(atomIds=(4, 5, 6, 7, 8), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(10,), atoms='Cl', type='CCl')])
# ('275: 2 fgs', [IFG(atomIds=(4, 5, 6, 7, 8), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(10,), atoms='Cl', type='CCl')])
# ('276: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('277: 1 fgs', [IFG(atomIds=(4,), atoms='Br', type='CBr')])
# ('278: 1 fgs', [IFG(atomIds=(14,), atoms='O', type='CO')])
# ('279: 1 fgs', [IFG(atomIds=(14,), atoms='O', type='CO')])
# ('280: 0 fgs', [])
# ('281: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O')])
# ('282: 1 fgs', [IFG(atomIds=(0, 1, 5), atoms='NC=O', type='CNC(C)=O')])
# ('283: 4 fgs', [IFG(atomIds=(1,), atoms='N', type='CN(C)C'), IFG(atomIds=(11,), atoms='s', type='csc'), IFG(atomIds=(5,), atoms='N', type='cN(C)C'), IFG(atomIds=(17,), atoms='n', type='cnc')])
# ('284: 1 fgs', [IFG(atomIds=(1,), atoms='S', type='cSC')])
# ('285: 0 fgs', [])
# ('286: 3 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(3,), atoms='Cl', type='cCl')])
# ('287: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 9), atoms='NP(O)(O)=S', type='cOP(=S)(NC)OC'), IFG(atomIds=(16, 17, 18), atoms='O=CO', type='cC(=O)OC')])
# ('288: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('289: 0 fgs', [])
# ('290: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='CO')])
# ('291: 1 fgs', [IFG(atomIds=(5,), atoms='n', type='cnc')])
# ('292: 5 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(8,), atoms='n', type='cnc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('293: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(N)=O', type='C=CC(N)=O')])
# ('294: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='C=CC(N)=O', type='C=CC(N)=O')])
# ('295: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='O', type='cOc'), IFG(atomIds=(16,), atoms='O', type='cOc')])
# ('296: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='O', type='cOc'), IFG(atomIds=(16,), atoms='O', type='cOc')])
# ('297: 1 fgs', [IFG(atomIds=(2,), atoms='Cl', type='CCl')])
# ('298: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#C')])
# ('299: 7 fgs', [IFG(atomIds=(3,), atoms='O', type='COC'), IFG(atomIds=(18, 5, 6), atoms='N=Cn', type='cN=C(C)n(c)c'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='F', type='CF'), IFG(atomIds=(16,), atoms='F', type='CF'), IFG(atomIds=(17,), atoms='F', type='CF'), IFG(atomIds=(21,), atoms='n', type='cnc')])
# ('300: 4 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('301: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8, 9, 7), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('302: 1 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=CO', type='COC(C)=O')])
# ('303: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=O', type='cC=O')])
# ('304: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(9,), atoms='N', type='cN'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('305: 1 fgs', [IFG(atomIds=(2,), atoms='I', type='CI')])
# ('306: 1 fgs', [IFG(atomIds=(3,), atoms='n', type='cnc')])
# ('307: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='cC=Cc')])
# ('308: 1 fgs', [IFG(atomIds=(3, 4), atoms='C=O', type='CC(C)=O')])
# ('309: 2 fgs', [IFG(atomIds=(0, 1), atoms='C=O', type='cC=O'), IFG(atomIds=(6,), atoms='o', type='coc')])
# ('310: 0 fgs', [])
# ('311: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOC'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('312: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOC'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('313: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(11,), atoms='O', type='cOC'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl'), IFG(atomIds=(18,), atoms='Cl', type='CCl')])
# ('314: 1 fgs', [IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('315: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC')])
# ('316: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='Br', type='CBr')])
# ('317: 1 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O')])
# ('318: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('319: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4, 5, 6), atoms='N=C(N)N[N+](=O)[O-]', type='N=C(N)N[N+](=O)[O-]')])
# ('320: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='O', type='cOC'), IFG(atomIds=(12,), atoms='O', type='cO')])
# ('321: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cNC(=O)Oc')])
# ('322: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cNC(=O)OC'), IFG(atomIds=(10, 11, 12, 13), atoms='NC(=O)O', type='cNC(=O)Oc')])
# ('323: 0 fgs', [])
# ('324: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('325: 0 fgs', [])
# ('326: 2 fgs', [IFG(atomIds=(14,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('327: 0 fgs', [])
# ('328: 0 fgs', [])
# ('329: 2 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(17, 18, 19), atoms='O=CO', type='cC(=O)OC')])
# ('330: 1 fgs', [IFG(atomIds=(8, 9, 10), atoms='O=CO', type='COC(C)=O')])
# ('331: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='CO')])
# ('332: 1 fgs', [IFG(atomIds=(4,), atoms='N', type='CN(C)C')])
# ('333: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(9,), atoms='N', type='cN(C)C')])
# ('334: 0 fgs', [])
# ('335: 1 fgs', [IFG(atomIds=(1,), atoms='I', type='CI')])
# ('336: 1 fgs', [IFG(atomIds=(8,), atoms='N', type='CN')])
# ('337: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='O', type='cOc')])
# ('338: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9,), atoms='O', type='cO')])
# ('339: 2 fgs', [IFG(atomIds=(2, 3, 4), atoms='OCO', type='cOC(C)OC'), IFG(atomIds=(9, 10, 12, 13), atoms='O=S(=O)O', type='cOS(C)(=O)=O')])
# ('340: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('341: 2 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='cC(=O)OC'), IFG(atomIds=(13, 14, 15), atoms='O=CO', type='cC(=O)OC')])
# ('342: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='O', type='cOc'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('343: 6 fgs', [IFG(atomIds=(2,), atoms='N', type='cNC'), IFG(atomIds=(4,), atoms='n', type='cnc'), IFG(atomIds=(6,), atoms='N', type='cNC'), IFG(atomIds=(11,), atoms='n', type='cnc'), IFG(atomIds=(13,), atoms='S', type='cSC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# ('344: 6 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(3,), atoms='n', type='cnc'), IFG(atomIds=(5,), atoms='N', type='cNC'), IFG(atomIds=(9,), atoms='n', type='cnc'), IFG(atomIds=(11,), atoms='N', type='cNC'), IFG(atomIds=(15,), atoms='n', type='cnc')])
# ('345: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('346: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(11,), atoms='O', type='cOC')])
# ('347: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='CO')])
# ('348: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='cO')])
# ('349: 5 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('350: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl')])
# ('351: 0 fgs', [])
# ('352: 3 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='O', type='cOc'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('353: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='o', type='coc')])
# ('354: 1 fgs', [IFG(atomIds=(5,), atoms='O', type='cO')])
# ('355: 4 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10, 11, 12), atoms='O=CO', type='cC(=O)O')])
# ('356: 1 fgs', [IFG(atomIds=(8,), atoms='O', type='cO')])
# ('357: 1 fgs', [IFG(atomIds=(6,), atoms='s', type='csc')])
# ('358: 1 fgs', [IFG(atomIds=(6,), atoms='s', type='csc')])
# ('359: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('360: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9, 10, 11), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('361: 6 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('362: 6 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(3,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('363: 1 fgs', [IFG(atomIds=(5, 6), atoms='C=O', type='CC=O')])
# ('364: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('365: 2 fgs', [IFG(atomIds=(8, 7), atoms='N=N', type='cN=Nc'), IFG(atomIds=(1,), atoms='N', type='cN(C)C')])
# ('366: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='o', type='coc'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl')])
# ('367: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='CC(=O)O'), IFG(atomIds=(8, 6, 7), atoms='O=CO', type='CC(=O)O')])
# ('368: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N')])
# ('369: 9 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(20,), atoms='Cl', type='cCl')])
# ('370: 2 fgs', [IFG(atomIds=(8, 6, 7), atoms='NC=O', type='cNC(c)=O'), IFG(atomIds=(2,), atoms='o', type='coc')])
# ('371: 1 fgs', [IFG(atomIds=(8, 9, 7), atoms='O=CO', type='COC(C)=O')])
# ('372: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('373: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('374: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=O', type='CC(C)=O')])
# ...
# ('906: 5 fgs', [IFG(atomIds=(4, 5), atoms='C=O', type='CC(C)=O'), IFG(atomIds=(7,), atoms='O', type='cOC'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(19, 15), atoms='nn', type='cnn(c)C'), IFG(atomIds=(17,), atoms='n', type='cnc')])
# ('907: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='CO')])
# ('908: 3 fgs', [IFG(atomIds=(9, 10, 11), atoms='NC=O', type='cN(C)C(C)=O'), IFG(atomIds=(13,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='O', type='COC')])
# ('909: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='CO')])
# ('910: 4 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('911: 0 fgs', [])
# ('912: 0 fgs', [])
# ('913: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=C(C)C')])
# ('914: 1 fgs', [IFG(atomIds=(8, 9, 7), atoms='O=CO', type='CC(=O)O')])
# ('915: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(5,), atoms='Cl', type='cCl')])
# ('916: 4 fgs', [IFG(atomIds=(0,), atoms='O', type='CO'), IFG(atomIds=(8,), atoms='O', type='CO'), IFG(atomIds=(4,), atoms='O', type='CO'), IFG(atomIds=(6,), atoms='O', type='CO')])
# ('917: 2 fgs', [IFG(atomIds=(9,), atoms='O', type='cOC'), IFG(atomIds=(2, 5, 6), atoms='NC=O', type='CC(=O)N(C)C')])
# ('918: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(3, 4), atoms='nn', type='c-n(c)nc'), IFG(atomIds=(12,), atoms='O', type='c=O'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('919: 4 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(3, 4), atoms='nn', type='c-n(c)nc'), IFG(atomIds=(12,), atoms='O', type='c=O'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('920: 2 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='O=P(O)(O)O', type='cOP(=O)(OC)OC'), IFG(atomIds=(13, 14, 15), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('921: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='COC')])
# ('922: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('923: 2 fgs', [IFG(atomIds=(10, 11, 12, 14, 15), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('924: 2 fgs', [IFG(atomIds=(10, 11, 12, 14, 15), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('925: 2 fgs', [IFG(atomIds=(10, 11, 12, 14, 15), atoms='O=CNCO', type='cN(COC)C(C)=O'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('926: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('927: 0 fgs', [])
# ('928: 1 fgs', [IFG(atomIds=(2, 3, 5), atoms='O=CO', type='COC(C)=O')])
# ('929: 2 fgs', [IFG(atomIds=(2,), atoms='Br', type='CBr'), IFG(atomIds=(4,), atoms='Br', type='CBr')])
# ('930: 9 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(18,), atoms='Cl', type='cCl'), IFG(atomIds=(20,), atoms='Cl', type='cCl')])
# ('931: 4 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(7,), atoms='O', type='cOc'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('932: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='C=CCl', type='C=C(C)Cl'), IFG(atomIds=(4, 5, 6, 7), atoms='NC(=S)S', type='CSC(=S)N(C)C')])
# ('933: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(8, 6, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('934: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('935: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('936: 3 fgs', [IFG(atomIds=(1, 2, 4, 5, 6), atoms='NC(=O)NO', type='cNC(=O)N(C)OC'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('937: 7 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('938: 1 fgs', [IFG(atomIds=(5, 6, 7), atoms='O=CO', type='COC=O')])
# ('939: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8, 9, 10), atoms='OP(O)(=S)SCS', type='COP(=S)(OC)SCSC')])
# ('940: 1 fgs', [IFG(atomIds=(2, 3, 4, 5, 8, 9, 10), atoms='OP(O)(=S)SCS', type='COP(=S)(OC)SCSC')])
# ('941: 2 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=C(C)C'), IFG(atomIds=(5, 6), atoms='C=C', type='CC=C(C)C')])
# ('942: 3 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('943: 3 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('944: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(9, 10, 11), atoms='O=CO', type='cC(=O)O')])
# ('945: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(9, 10, 11), atoms='O=CO', type='cC(=O)O')])
# ('946: 1 fgs', [IFG(atomIds=(3, 5), atoms='C=O', type='CC(C)=O')])
# ('947: 3 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=CO', type='COC(C)=O'), IFG(atomIds=(8, 9), atoms='C#N', type='CC#N'), IFG(atomIds=(15,), atoms='O', type='cOc')])
# ('948: 4 fgs', [IFG(atomIds=(2, 3, 4, 5, 8), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(10,), atoms='n', type='cnc'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(17, 13), atoms='nn', type='cnn(c)C')])
# ('949: 1 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='NC(N)=O', type='NC(N)=O')])
# ('950: 1 fgs', [IFG(atomIds=(0, 1, 2, 3, 4), atoms='ClC=C(Cl)Cl', type='ClC=C(Cl)Cl')])
# ('951: 2 fgs', [IFG(atomIds=(3, 4, 5), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(10, 11, 12), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('952: 1 fgs', [IFG(atomIds=(6,), atoms='n', type='cnc')])
# ('953: 1 fgs', [IFG(atomIds=(1, 3, 4, 5), atoms='NC(N)=O', type='cNC(=O)N(C)C')])
# ('954: 1 fgs', [IFG(atomIds=(3,), atoms='S', type='CSC')])
# ('955: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 7, 8), atoms='O=CNP(=O)(O)S', type='COP(=O)(NC(C)=O)SC')])
# ('956: 1 fgs', [IFG(atomIds=(4, 5), atoms='NN', type='cNNc')])
# ('957: 2 fgs', [IFG(atomIds=(0,), atoms='N', type='cN'), IFG(atomIds=(10,), atoms='N', type='cN')])
# ('958: 8 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(16,), atoms='Cl', type='cCl'), IFG(atomIds=(19,), atoms='Cl', type='cCl')])
# ('959: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='cO'), IFG(atomIds=(7,), atoms='O', type='cO')])
# ('960: 1 fgs', [IFG(atomIds=(5,), atoms='O', type='cO')])
# ('961: 1 fgs', [IFG(atomIds=(0, 1, 5), atoms='O=CO', type='COC(C)=O')])
# ('962: 2 fgs', [IFG(atomIds=(1, 2, 3, 4), atoms='NC(=O)O', type='cOC(=O)NC'), IFG(atomIds=(10,), atoms='S', type='cSC')])
# ('963: 4 fgs', [IFG(atomIds=(2,), atoms='n', type='cnc'), IFG(atomIds=(4,), atoms='N', type='cN(C)C'), IFG(atomIds=(7,), atoms='n', type='cnc'), IFG(atomIds=(9, 10, 11, 12), atoms='NC(=O)O', type='cOC(=O)N(C)C')])
# ('964: 1 fgs', [IFG(atomIds=(3,), atoms='N', type='CN(C)C')])
# ('965: 2 fgs', [IFG(atomIds=(0, 1, 2), atoms='O=CO', type='cC(=O)O'), IFG(atomIds=(9,), atoms='O', type='cO')])
# ('966: 0 fgs', [])
# ('967: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# ('968: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(4,), atoms='Cl', type='CCl')])
# ('969: 1 fgs', [IFG(atomIds=(8,), atoms='O', type='CO')])
# ('970: 1 fgs', [IFG(atomIds=(3, 4, 6), atoms='O=CO', type='COC(C)=O')])
# ('971: 1 fgs', [IFG(atomIds=(3,), atoms='o', type='coc')])
# ('972: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(2,), atoms='Cl', type='CCl')])
# ('973: 2 fgs', [IFG(atomIds=(2,), atoms='O', type='COC'), IFG(atomIds=(5,), atoms='N', type='CNC')])
# ('974: 0 fgs', [])
# ('975: 0 fgs', [])
# ('976: 3 fgs', [IFG(atomIds=(0, 1), atoms='C#N', type='cC#N'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(4,), atoms='Cl', type='cCl')])
# ('977: 2 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('978: 1 fgs', [IFG(atomIds=(9, 10, 11), atoms='O=CO', type='COC(C)=O')])
# ('979: 2 fgs', [IFG(atomIds=(1, 2), atoms='C=O', type='CC(C)=O'), IFG(atomIds=(4, 6), atoms='C=O', type='CC(C)=O')])
# ('980: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl')])
# ('981: 1 fgs', [IFG(atomIds=(3,), atoms='s', type='csc')])
# ('982: 0 fgs', [])
# ('983: 2 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(7,), atoms='Cl', type='cCl')])
# ('984: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('985: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(15,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl')])
# ('986: 1 fgs', [IFG(atomIds=(0, 1), atoms='C#C', type='C#CC')])
# ('987: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# ('988: 5 fgs', [IFG(atomIds=(1,), atoms='n', type='cn(c)C'), IFG(atomIds=(11,), atoms='O', type='c=O'), IFG(atomIds=(19,), atoms='F', type='CF'), IFG(atomIds=(20,), atoms='F', type='CF'), IFG(atomIds=(21,), atoms='F', type='CF')])
# ('989: 0 fgs', [])
# ('990: 1 fgs', [IFG(atomIds=(0,), atoms='O', type='cO')])
# ('991: 1 fgs', [IFG(atomIds=(5,), atoms='Br', type='CBr')])
# ('992: 1 fgs', [IFG(atomIds=(8, 9, 7), atoms='O=CO', type='COC(C)=O')])
# ('993: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(9,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl')])
# ('994: 1 fgs', [IFG(atomIds=(5,), atoms='Br', type='CBr')])
# ('995: 6 fgs', [IFG(atomIds=(1,), atoms='O', type='cOC'), IFG(atomIds=(4,), atoms='O', type='cO'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('996: 1 fgs', [IFG(atomIds=(3,), atoms='O', type='COC')])
# ('997: 1 fgs', [IFG(atomIds=(8, 10), atoms='C=O', type='CC(C)=O')])
# ('998: 1 fgs', [IFG(atomIds=(5,), atoms='Br', type='cBr')])
# ('999: 3 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='C=C(Cl)Cl', type='cC(c)=C(Cl)Cl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('1000: 1 fgs', [IFG(atomIds=(3,), atoms='S', type='CSC')])
# ('1001: 0 fgs', [])
# ('1002: 1 fgs', [IFG(atomIds=(3,), atoms='[nH]', type='c[nH]c')])
# ('1003: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='C=CC')])
# ('1004: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl')])
# ('1005: 0 fgs', [])
# ('1006: 0 fgs', [])
# ('1007: 5 fgs', [IFG(atomIds=(2,), atoms='O', type='cOC'), IFG(atomIds=(6,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(11,), atoms='Cl', type='cCl'), IFG(atomIds=(12, 13, 14), atoms='O=CO', type='CC(=O)O')])
# ('1008: 1 fgs', [IFG(atomIds=(2,), atoms='N', type='CN(C)C')])
# ('1009: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl')])
# ('1010: 0 fgs', [])
# ('1011: 2 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(11, 12, 13), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1012: 2 fgs', [IFG(atomIds=(1, 2, 3, 4, 6), atoms='OP(O)(O)=S', type='cOP(=S)(OC)OC'), IFG(atomIds=(11, 12, 13), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1013: 3 fgs', [IFG(atomIds=(0,), atoms='Cl', type='CCl'), IFG(atomIds=(3,), atoms='O', type='COC'), IFG(atomIds=(6,), atoms='Cl', type='CCl')])
# ('1014: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='CO')])
# ('1015: 1 fgs', [IFG(atomIds=(4, 5, 6, 7, 12), atoms='O=P(S)(S)S', type='CSP(=O)(SC)SC')])
# ('1016: 1 fgs', [IFG(atomIds=(3, 4, 5, 12, 13, 14, 15), atoms='NS(=O)(=O)NC=O', type='CN1C(=O)ccNS1(=O)=O')])
# ('1017: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('1018: 2 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(6,), atoms='Cl', type='cCl')])
# ('1019: 1 fgs', [IFG(atomIds=(5, 6, 7), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1020: 1 fgs', [IFG(atomIds=(8, 6), atoms='C=O', type='CC(C)=O')])
# ('1021: 3 fgs', [IFG(atomIds=(1,), atoms='O', type='COC'), IFG(atomIds=(3, 4, 5), atoms='NC=O', type='cN(C)C(C)=O'), IFG(atomIds=(16, 17, 18), atoms='O=CO', type='COC(C)=O')])
# ('1022: 6 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(7,), atoms='Cl', type='cCl'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl'), IFG(atomIds=(17,), atoms='Cl', type='cCl')])
# ('1023: 1 fgs', [IFG(atomIds=(1, 2, 3, 4, 5, 6), atoms='NC(=O)NN=O', type='CN(N=O)C(N)=O')])
# ('1024: 5 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(5,), atoms='O', type='cOc'), IFG(atomIds=(10,), atoms='Cl', type='cCl'), IFG(atomIds=(13,), atoms='Cl', type='cCl'), IFG(atomIds=(15,), atoms='Cl', type='cCl')])
# ('1025: 6 fgs', [IFG(atomIds=(3,), atoms='N', type='cN(C)C'), IFG(atomIds=(9, 10, 11), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(15,), atoms='F', type='CF'), IFG(atomIds=(16,), atoms='F', type='CF'), IFG(atomIds=(17,), atoms='F', type='CF'), IFG(atomIds=(20, 21, 22), atoms='O=[N+][O-]', type='c[N+](=O)[O-]')])
# ('1026: 1 fgs', [IFG(atomIds=(6,), atoms='O', type='CO')])
# ('1027: 1 fgs', [IFG(atomIds=(3, 4), atoms='C=O', type='CC=O')])
# ('1028: 0 fgs', [])
# ('1029: 1 fgs', [IFG(atomIds=(2, 4), atoms='C=O', type='CC(C)=O')])
# ('1030: 4 fgs', [IFG(atomIds=(0,), atoms='Cl', type='cCl'), IFG(atomIds=(8,), atoms='Cl', type='cCl'), IFG(atomIds=(12,), atoms='Cl', type='cCl'), IFG(atomIds=(14,), atoms='Cl', type='cCl')])
# ('1031: 1 fgs', [IFG(atomIds=(9,), atoms='O', type='CO')])
# ('1032: 1 fgs', [IFG(atomIds=(4,), atoms='O', type='CO')])
# ('1033: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8, 9, 7), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('1034: 7 fgs', [IFG(atomIds=(0, 1, 2, 3), atoms='ClC=CCl', type='CC(Cl)=C(C)Cl'), IFG(atomIds=(5,), atoms='Cl', type='CCl'), IFG(atomIds=(8, 9, 7), atoms='C1CO1', type='CC1OC1C'), IFG(atomIds=(11,), atoms='Cl', type='CCl'), IFG(atomIds=(14,), atoms='Cl', type='CCl'), IFG(atomIds=(16,), atoms='Cl', type='CCl'), IFG(atomIds=(17,), atoms='Cl', type='CCl')])
# ('1035: 1 fgs', [IFG(atomIds=(0, 1), atoms='C=C', type='CC=CC')])
# ('1036: 3 fgs', [IFG(atomIds=(4, 5, 6), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(9, 10, 11), atoms='O=[N+][O-]', type='c[N+](=O)[O-]'), IFG(atomIds=(13,), atoms='O', type='cO')])
# ('1037: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='c=O'), IFG(atomIds=(10,), atoms='o', type='coc')])
# ('1038: 2 fgs', [IFG(atomIds=(0,), atoms='O', type='c=O'), IFG(atomIds=(10,), atoms='o', type='coc')])
# NoneType

# %%
#I copied this output into excel so i colud add it to the spread sheet
